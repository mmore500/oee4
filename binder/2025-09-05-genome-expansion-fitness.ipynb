# %%
# %load_ext watermark

# %%
import boto3
import botocore
from io import StringIO
from iterdub import iterdub as ib
from iterpop import iterpop as ip
from matplotlib import pyplot as plt
import pandas as pd
from pandas.util import hash_pandas_object
import re
import seaborn as sns
import statsmodels.api as sm
from teeplot import teeplot as tp

# %%
import os

from IPython.display import display
import seaborn as sns
from teeplot import teeplot as tp

# from dishpylib.pyhelpers import make_outattr_metadata
# from dishpylib.pyhelpers import print_runtime

# %%
# %watermark -diwmuv -iv
# Out:
# Last updated: 2025-09-06T00:39:51.567610+00:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 7.16.1
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.8.0-1031-azure
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
# boto3      : 1.14.44
# matplotlib : 3.5.3
# seaborn    : 0.13.2
# teeplot    : 1.4.2
# iterpop    : 0.3.4
# statsmodels: 0.13.5
# botocore   : 1.17.44
# re         : 2.2.1
# pandas     : 1.4.4
# iterdub    : 0.2.0
#
# Watermark: 2.4.3

# %%
teeplot_subdir = os.environ.get(
    "NOTEBOOK_NAME", "2025-09-05-genome-expansion-fitness"
)
teeplot_subdir
# Out:
# '2025-09-05-genome-expansion-fitness'

# %% [markdown]
# # get data

# %%
s3_handle = boto3.resource(
    's3',
    region_name="us-east-2",
    config=botocore.config.Config(
        signature_version=botocore.UNSIGNED,
    ),
)
bucket_handle = s3_handle.Bucket('prq49')

series_profiles, = bucket_handle.objects.filter(
    Prefix=f'endeavor=16/series-profiles/stage=8+what=elaborated/',
)

# %%
df = pd.read_csv(
    f's3://prq49/{series_profiles.key}',
    compression='xz',
)
dfdigest = '{:x}'.format(hash_pandas_object( df ).sum())
dfdigest
# Out:
# <ipython-input-7-06b399353b17>:1: DtypeWarning: Columns (2270,2277,2284,2285,2286,2287,2289,2290,2291,2292,2298,2299,2300,2301,2302,2308,2309,2310) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# '-1af9f0eb89153a8e'

# %% [markdown]
# # set up graphing utilities

# %%
def letterscatter(*,data,x,y,cat):
    sns.scatterplot(
        data=data,
        x=x,
        y=y,
        color='k',
        edgecolor='k',
        s=200,
    )
    sns.scatterplot(
        data=data,
        x=x,
        y=y,
        hue=cat,
        edgecolor=None,
        s=120,
    )
    sns.scatterplot(
        data=data,
        x=x,
        y=y,
        color='w',
        style=cat,
        markers={
            phen : f'$\mathrm{{{phen}}}$'
            for phen in data[cat].unique()
        },
        legend=False,
    )
    plt.legend(
        bbox_to_anchor=(1.01, 1),
        borderaxespad=0,
        title='Morph',
        frameon=False,
    )

# %%
def letterscatter_vline(*args, **kwargs):
    letterscatter(*args, **kwargs)
    plt.axvline(15,zorder=-2,c='k',ls=':')
    plt.axvline(45,zorder=-2,c='k',ls='--')

# %%
def letterscatter_vline_interpolationmissing(*args, **kwargs):
    letterscatter_vline(*args, **kwargs)

    for stint in dfx[ dfx['a=most_credible_idx+set_size=1'].isnull() ]['Stint']:
        plt.axvline(stint, c='gray', zorder=-2, alpha=0.5)

# %% [markdown]
# # preprocess data

# %%
morph_csv = StringIO('''Stint,Morph,Series
0,a,16005
1,b,16005
2,c,16005
3,b,16005
4,b,16005
5,b,16005
6,b,16005
7,b,16005
8,b,16005
9,b,16005
10,b,16005
11,b,16005
0,1,97,16005,10,12634
0,2,97,16005,15,12634
0,3,97,16005,11,12634
0,0,98,16005,17,12634
0,1,98,16005,17,12634
0,2,98,16005,21,12634
0,3,98,16005,16,12634
0,0,99,16005,19,12634
0,1,99,16005,15,12634
0,2,99,16005,21,12634
0,3,99,16005,15,12634
0,0,9,16005,6,12634
0,1,9,16005,5,12634
0,2,9,16005,3,12634
0,3,9,16005,5,12634
''')

df_lowestroot_phylo = pd.read_csv(lowestroot_phylo_csv).groupby([
    'Series',
    'Stint',
]).mean(
    numeric_only=True,
).reset_index()

# %%
df = pd.merge(
    df,
    df_lowestroot_phylo,
    on=['Stint', 'Series'],
    how='outer',
)

# %%
dfm10 = df[ df['Stint'] % 10 == 0 ]

# %%
dfx = df[ df['Series'] == 16005 ].sort_values('Morph')

# %%
for col in df.columns:
    print(col)
# Out:
# Repro
# Endeavor
# Slurm Job ID
# N_THREADS
# RUN
# RUN_UPDATES
# RUN_SECONDS
# MAIN_TIMEOUT_SECONDS
# END_SNAPSHOT_TIMEOUT_SECONDS
# LOG_FREQ
# ASYNCHRONOUS
# SYNC_FREQ_MILLISECONDS
# RNG_PRESEED
# THROW_ON_EXTINCTION
# RUN_SLUG
# PHENOTYPIC_DIVERGENCE_N_UPDATES
# PHENOTYPIC_DIVERGENCE_N_CELLS
# STINT
# SERIES
# REPLICATE
# TREATMENT
# SEED_FILL_FRACTION
# GENESIS
# N_CELLS
# WEAK_SCALING
# N_DIMS
# GROUP_EXPIRATION_DURATIONS
# CELL_AGE_DURATION
# MIN_START_RESOURCE
# MAX_START_RESOURCE
# RESOURCE_DECAY
# APOP_RECOVERY_FRAC
# SPAWN_DEFENSE_COST
# BASE_HARVEST_RATE
# COLLECTIVE_HARVEST_RATE
# OPTIMAL_QUORUM_COUNT
# P_SET_QUORUM_BIT
# QUORUM_CAP
# P_QUORUM_CAP_KILL
# PROGRAM_START_SIZE
# PROGRAM_MAX_SIZE
# MUTATION_RATE
# POINT_MUTATION_RATE
# SEQUENCE_DEFECT_RATE
# MINOR_SEQUENCE_MUTATION_BOUND
# SEVERE_SEQUENCE_MUTATION_RATE
# HARDWARE_EXECUTION_ROUNDS
# HARDWARE_EXECUTION_CYCLES
# CONTROLLER_MAPPED_STATE_DEFECT_RATE
# APOPTOSIS_SERVICE_FREQUENCY
# BIRTH_SETUP_SERVICE_FREQUENCY
# CELL_AGE_SERVICE_FREQUENCY
# CONDUIT_FLUSH_SERVICE_FREQUENCY
# COLLECTIVE_HARVESTING_SERVICE_FREQUENCY
# CPU_EXECUTION_SERVICE_FREQUENCY
# GROUP_EXPIRATION_SERVICE_FREQUENCY
# RUNNING_LOG_PURGE_SERVICE_FREQUENCY
# DIVERSITY_MAINTENANCE_SERVICE_FREQUENCY
# DIVERSITY_MAINTENANCE_PREVALENCE
# STINT_DIVERSITY_MAINTENANCE_SERVICE_FREQUENCY
# STINT_DIVERSITY_MAINTENANCE_PREVALENCE
# DECAY_TO_BASELINE_SERVICE_FREQUENCY
# EPOCH_ADVANCE_SERVICE_FREQUENCY
# EVENT_LAUNCHING_SERVICE_FREQUENCY
# INTERMITTENT_CPU_RESET_SERVICE_FREQUENCY
# INTERMITTENT_STATE_PERTURB_SERVICES_FREQUENCY
# INTER_MESSAGE_COUNTER_CLEAR_SERVICE_FREQUENCY
# INTER_MESSAGE_LAUNCHING_SERVICE_FREQUENCY
# INTRA_MESSAGE_LAUNCHING_SERVICE_FREQUENCY
# STATE_OUTPUT_PUT_SERVICE_FREQUENCY
# PUSH_SERVICE_FREQUENCY
# QUORUM_CAP_SERVICE_FREQUENCY
# QUORUM_SERVICE_FREQUENCY
# RESOURCE_DECAY_SERVICE_FREQUENCY
# RESOURCE_HARVESTING_SERVICE_FREQUENCY
# RESOURCE_INPUT_JUMP_SERVICE_FREQUENCY
# RESOURCE_RECEIVING_SERVICE_FREQUENCY
# RESOURCE_SENDING_SERVICE_FREQUENCY
# SPAWN_SENDING_SERVICE_FREQUENCY
# STATE_INPUT_JUMP_SERVICE_FREQUENCY
# CONTROLLER_MAPPED_STATE_NOISE_SERVICE_FREQUENCY
# PHENOTYPE_EQUIVALENT_NOPOUT
# BATTLESHIP_PHENOTYPE_EQUIVALENT_NOPOUT
# JENGA_PHENOTYPE_EQUIVALENT_NOPOUT
# JENGA_NOP_OUT_SAVE_PROGRESS_AND_QUIT_SECONDS
# TEST_INTERROOT_PHENOTYPE_DIFFERENTIATION
# ALL_DRAWINGS_WRITE
# DATA_DUMP
# RUNNINGLOGS_DUMP
# CENSUS_WRITE
# ARTIFACTS_DUMP
# BENCHMARKING_DUMP
# ROOT_ABUNDANCES_FREQ
# ABORT_IF_COALESCENT_FREQ
# ABORT_IF_EXTINCT_FREQ
# ABORT_AT_LIVE_CELL_FRACTION
# REGULATION_VIZ_CLAMP
# RUNNING_LOG_DURATION
# SELECTED_DRAWINGS_FREQ
# DRAWING_WIDTH_PX
# DRAWING_HEIGHT_PX
# SELECTED_DRAWINGS
# ANIMATE_FRAMES
# VIDEO_FPS
# VIDEO_MAX_FRAMES
# Series
# Stint
# Stint_x
# Mean Inter-Strain Fitness Differential
# Stint_y
# Fraction Inter-Strain Competitions Won
# Inter-Strain Competition Null p-value
# Flagged Advantageous Sites
# Flagged Deleterious Sites
# H_0 Advantageous Site Flags
# H_0 Deleterious Site Flags
# Estimated True Advantageous Sites
# Estimated True Deleterious Sites
# Num More Fit Under Extrospective State Rotates @ Intermittent P 1
# Num Less Fit Under Extrospective State Rotates @ Intermittent P 1
# Fraction Extrospective State Rotates that are Advantageous @ Intermittent P 1
# Fraction Extrospective State Rotates that are Deleterious @ Intermittent P 1
# Mean Extrospective State Rotate Fitness Differential @ Intermittent P 1
# Median Extrospective State Rotate Fitness Differential @ Intermittent P 1
# Is More Fit Under Extrospective State 0 Rotates @ Intermittent P 1
# Is Less Fit Under Extrospective State 0 Rotates @ Intermittent P 1
# Extrospective State 0 Rotate Fitness Differential @ Intermittent P 1
# Is More Fit Under Extrospective State 1 Rotates @ Intermittent P 1
# Is Less Fit Under Extrospective State 1 Rotates @ Intermittent P 1
# Extrospective State 1 Rotate Fitness Differential @ Intermittent P 1
# Is More Fit Under Extrospective State 2 Rotates @ Intermittent P 1
# Is Less Fit Under Extrospective State 2 Rotates @ Intermittent P 1
# Extrospective State 2 Rotate Fitness Differential @ Intermittent P 1
# Is More Fit Under Extrospective State 3 Rotates @ Intermittent P 1
# Is Less Fit Under Extrospective State 3 Rotates @ Intermittent P 1
# Extrospective State 3 Rotate Fitness Differential @ Intermittent P 1
# Is More Fit Under Extrospective State 4 Rotates @ Intermittent P 1
# Is Less Fit Under Extrospective State 4 Rotates @ Intermittent P 1
# Extrospective State 4 Rotate Fitness Differential @ Intermittent P 1
# Is More Fit Under Extrospective State 5 Rotates @ Intermittent P 1
# Is Less Fit Under Extrospective State 5 Rotates @ Intermittent P 1
# Extrospective State 5 Rotate Fitness Differential @ Intermittent P 1
# Is More Fit Under Extrospective State 6 Rotates @ Intermittent P 1
# Is Less Fit Under Extrospective State 6 Rotates @ Intermittent P 1
# Extrospective State 6 Rotate Fitness Differential @ Intermittent P 1
# Is More Fit Under Extrospective State
# Is Less Fit Under Extrospective State 52 Exchanges
# Extrospective State 52 Exchange Fitness Differential
# Is More Fit Under Extrospective State 53 Exchanges
# Is Less Fit Under Extrospective State 53 Exchanges
# Extrospective State 53 Exchange Fitness Differential
# Is More Fit Under Extrospective State 54 Exchanges
# Is Less Fit Under Extrospective State 54 Exchanges
# Extrospective State 54 Exchange Fitness Differential
# Is More Fit Under Extrospective State 55 Exchanges
# ...
# Mean Cell Age (monoculture mean)
# Mean Current Epoch (monoculture mean)
# Mean Elapsed Generations Level 0 (monoculture mean)
# Mean Elapsed Generations Level 1 (monoculture mean)
# Mean Elapsed Generations Level 2 (monoculture mean)
# Mean Elapsed Indel Mutations (monoculture mean)
# Mean Elapsed Mutation Occurences (monoculture mean)
# Mean Elapsed Point Mutations (monoculture mean)
# Mean Incoming Inter Message Count Per Cardinal (monoculture mean)
# Mean Incoming Inter Message Count Per Cell (monoculture mean)
# Mean Incoming Intra Message Count Per Cardinal (monoculture mean)
# Mean Incoming Intra Message Count Per Cell (monoculture mean)
# Mean Instructions Executed per Cardinal-update (monoculture mean)
# Mean Kin Group Age Level 0 (monoculture mean)
# Mean Kin Group Age Level 1 (monoculture mean)
# Mean Kin Group Size Level 0 (monoculture mean)
# Mean Kin Group Size Level 1 (monoculture mean)
# Mean Program Instruction Count (monoculture mean)
# Mean Program Module Count (monoculture mean)
# Mean Resource Received Per Cardinal (monoculture mean)
# Mean Resource Received Per Cell (monoculture mean)
# Mean Resource Stockpile (monoculture mean)
# Mean Spawn Count (monoculture mean)
# Median Kin Group Size Level 0 (monoculture mean)
# Median Kin Group Size Level 1 (monoculture mean)
# Nulliparous Fraction (monoculture mean)
# Num Births per Cell-update (monoculture mean)
# Num Births per Live Cell-update  (monoculture mean)
# Num Deaths age (monoculture mean)
# Num Deaths apoptosis (monoculture mean)
# Num Deaths elimination (monoculture mean)
# Num Deaths fragmentation (monoculture mean)
# Num Deaths per Cell-update (monoculture mean)
# Num Deaths per Cell-update age (monoculture mean)
# Num Deaths per Cell-update apoptosis (monoculture mean)
# Num Deaths per Cell-update elimination (monoculture mean)
# Num Deaths per Cell-update fragmentation (monoculture mean)
# Num Deaths per Cell-update quorum (monoculture mean)
# Num Deaths per Cell-update unknown (monoculture mean)
# Num Deaths per Live Cell-update  (monoculture mean)
# Num Deaths per Live Cell-update age (monoculture mean)
# Num Deaths per Live Cell-update apoptosis (monoculture mean)
# Num Deaths per Live Cell-update elimination (monoculture mean)
# Num Deaths per Live Cell-update fragmentation (monoculture mean)
# Num Deaths per Live Cell-update quorum (monoculture mean)
# Num Deaths per Live Cell-update unknown (monoculture mean)
# Num Deaths quorum (monoculture mean)
# Num Deaths unknown (monoculture mean)
# Num Instructions Executed per Live Cardinal-update (monoculture mean)
# Num Spawn Events per Cell-update (monoculture mean)
# Num Spawn Events per Live Cell-update  (monoculture mean)
# Number Cardinals (monoculture mean)
# Number Cells (monoculture mean)
# Number Dead Cells (monoculture mean)
# Number Live Cardinals (monoculture mean)
# Number Live Cells (monoculture mean)
# Number Phylogenetic Roots (monoculture mean)
# Number Stint Phylogenetic Roots (monoculture mean)
# Number Unique Genotypes (monoculture mean)
# Number Unique Module Expression Profiles (monoculture mean)
# Number Unique Module Regulation Profiles (monoculture mean)
# Prevalent Genotype Quantity (monoculture mean)
# Random Number Generator Seed (monoculture mean)
# Resource Receive Resistance Cardinal Fraction (monoculture mean)
# Resource Receive Resistance Cell Fraction (monoculture mean)
# Resource Receiving Cardinal Fraction (monoculture mean)
# Resource Receiving Cell Fraction (monoculture mean)
# Resource Reserve Request Cardinal Fraction (monoculture mean)
# Resource Reserve Request Cell Fraction (monoculture mean)
# Resource Send Request Cardinal Fraction (monoculture mean)
# Resource Send Request Cell Fraction (monoculture mean)
# Spawn Arrest Cardinal Fraction (monoculture mean)
# Spawn Arrest Cell Fraction (monoculture mean)
# Spawn Request Cardinal Fraction (monoculture mean)
# Spawn Request Cell Fraction (monoculture mean)
# proc (evolve mean)
# thread (evolve mean)
# Update (evolve mean)
# Cardinal Apoptosis Request Fraction (evolve mean)
# Cell Apoptosis Request Fraction (evolve mean)
# Extinct (evolve mean)
# Fecund Resource Stockpile Fraction (evolve mean)
# Fraction Deaths age (evolve mean)
# Fraction Deaths apoptosis (evolve mean)
# Fraction Deaths elimination (evolve mean)
# Fraction Deaths fragmentation (evolve mean)
# Fraction Deaths quorum (evolve mean)
# Fraction Deaths unknown (evolve mean)
# Fraction Kin Group Loner Cells Level 0 (evolve mean)
# Fraction Kin Group Loner Cells Level 1 (evolve mean)
# Fraction Live Cells (evolve mean)
# Fraction Neighbors Kin Level 0 (evolve mean)
# Fraction Neighbors Kin Level 1 (evolve mean)
# Incoming Inter Message Cardinal Fraction (evolve mean)
# Incoming Inter Message Cell Fraction (evolve mean)
# Incoming Intra Message Cardinal Fraction (evolve mean)
# Incoming Intra Message Cell Fraction (evolve mean)
# Maximum Kin Group Size Level 0 (evolve mean)
# Maximum Kin Group Size Level 1 (evolve mean)
# Mean Cell Age (evolve mean)
# Mean Current Epoch (evolve mean)
# Mean Elapsed Generations Level 0 (evolve mean)
# Mean Elapsed Generations Level 1 (evolve mean)
# Mean Elapsed Generations Level 2 (evolve mean)
# Mean Elapsed Indel Mutations (evolve mean)
# Mean Elapsed Mutation Occurences (evolve mean)
# Mean Elapsed Point Mutations (evolve mean)
# Mean Incoming Inter Message Count Per Cardinal (evolve mean)
# Mean Incoming Inter Message Count Per Cell (evolve mean)
# Mean Incoming Intra Message Count Per Cardinal (evolve mean)
# Mean Incoming Intra Message Count Per Cell (evolve mean)
# Mean Instructions Executed per Cardinal-update (evolve mean)
# Mean Kin Group Age Level 0 (evolve mean)
# Mean Kin Group Age Level 1 (evolve mean)
# Mean Kin Group Size Level 0 (evolve mean)
# Mean Kin Group Size Level 1 (evolve mean)
# Mean Program Instruction Count (evolve mean)
# Mean Program Module Count (evolve mean)
# Mean Resource Received Per Cardinal (evolve mean)
# Mean Resource Received Per Cell (evolve mean)
# Mean Resource Stockpile (evolve mean)
# Mean Spawn Count (evolve mean)
# Median Kin Group Size Level 0 (evolve mean)
# Median Kin Group Size Level 1 (evolve mean)
# Nulliparous Fraction (evolve mean)
# Num Births per Cell-update (evolve mean)
# Num Births per Live Cell-update  (evolve mean)
# Num Deaths age (evolve mean)
# Num Deaths apoptosis (evolve mean)
# Num Deaths elimination (evolve mean)
# Num Deaths fragmentation (evolve mean)
# Num Deaths per Cell-update (evolve mean)
# Num Deaths per Cell-update age (evolve mean)
# Num Deaths per Cell-update apoptosis (evolve mean)
# Num Deaths per Cell-update elimination (evolve mean)
# Num Deaths per Cell-update fragmentation (evolve mean)
# Num Deaths per Cell-update quorum (evolve mean)
# Num Deaths per Cell-update unknown (evolve mean)
# Num Deaths per Live Cell-update  (evolve mean)
# Num Deaths per Live Cell-update age (evolve mean)
# Num Deaths per Live Cell-update apoptosis (evolve mean)
# Num Deaths per Live Cell-update elimination (evolve mean)
# Num Deaths per Live Cell-update fragmentation (evolve mean)
# Num Deaths per Live Cell-update quorum (evolve mean)
# Num Deaths per Live Cell-update unknown (evolve mean)
# Num Deaths quorum (evolve mean)
# Num Deaths unknown (evolve mean)
# Num Instructions Executed per Live Cardinal-update (evolve mean)
# Num Spawn Events per Cell-update (evolve mean)
# Num Spawn Events per Live Cell-update  (evolve mean)
# Number Cardinals (evolve mean)
# Number Cells (evolve mean)
# Number Dead Cells (evolve mean)
# Number Live Cardinals (evolve mean)
# Number Live Cells (evolve mean)
# Number Phylogenetic Roots (evolve mean)
# Number Stint Phylogenetic Roots (evolve mean)
# Number Unique Genotypes (evolve mean)
# Number Unique Module Expression Profiles (evolve mean)
# Number Unique Module Regulation Profiles (evolve mean)
# Prevalent Genotype Quantity (evolve mean)
# Random Number Generator Seed (evolve mean)
# Resource Receive Resistance Cardinal Fraction (evolve mean)
# Resource Receive Resistance Cell Fraction (evolve mean)
# Resource Receiving Cardinal Fraction (evolve mean)
# Resource Receiving Cell Fraction (evolve mean)
# Resource Reserve Request Cardinal Fraction (evolve mean)
# Resource Reserve Request Cell Fraction (evolve mean)
# Resource Send Request Cardinal Fraction (evolve mean)
# Resource Send Request Cell Fraction (evolve mean)
# Spawn Arrest Cardinal Fraction (evolve mean)
# Spawn Arrest Cell Fraction (evolve mean)
# Spawn Request Cardinal Fraction (evolve mean)
# Spawn Request Cell Fraction (evolve mean)
# Parent-Eliminated Kin ID Commonality=1+a=Treatment
# Parent-Eliminated Kin ID Commonality=2+a=Treatment
# Parent-Eliminated Kin ID Commonality=1+a=Treatment _
# Parent-Eliminated Kin ID Commonality=2+a=Treatment _
# Parent-Eliminated Kin ID Commonality=1+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=2+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=1+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=2+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=1+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=2+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=1+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=2+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=1+a=proc
# Parent-Eliminated Kin ID Commonality=2+a=proc
# Parent-Eliminated Kin ID Commonality=1+a=thread
# Parent-Eliminated Kin ID Commonality=2+a=thread
# Parent-Eliminated Kin ID Commonality=1+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=2+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Neighbors
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Neighbors
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Spawn Event Neighbors
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Spawn Event Neighbors
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Kin Eliminated
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Kin Eliminated
# Parent-Eliminated Kin ID Commonality=1+a=Fraction Eliminated that are Kin
# Parent-Eliminated Kin ID Commonality=2+a=Fraction Eliminated that are Kin
# Parent-Eliminated Kin ID Commonality=1+a=Fraction Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+a=Fraction Spawn Event Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+a=Fraction Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=2+a=Fraction Neighbors that are Kin
# Parent-Eliminated Kin ID Commonality=1+a=Kin Conflict Ratio
# Parent-Eliminated Kin ID Commonality=2+a=Kin Conflict Ratio
# Parent-Eliminated Kin ID Commonality=1+a=Kin Conflict at Spawn Ratio
# Parent-Eliminated Kin ID Commonality=2+a=Kin Conflict at Spawn Ratio
# Daughter-Eliminated Kin ID Commonality=0+Statistic=Count+What=birth (monoculture)
# Daughter-Eliminated Kin ID Commonality=1+Statistic=Count+What=birth (monoculture)
# Daughter-Eliminated Kin ID Commonality=2+Statistic=Count+What=birth (monoculture)
# Daughter-Eliminated Kin ID Commonality=0+Statistic=Frequency+What=birth (monoculture)
# Daughter-Eliminated Kin ID Commonality=1+Statistic=Frequency+What=birth (monoculture)
# Daughter-Eliminated Kin ID Commonality=2+Statistic=Frequency+What=birth (monoculture)
# Parent-Daughter Kin ID Commonality=0+Statistic=Count+What=birth (monoculture)
# Parent-Daughter Kin ID Commonality=1+Statistic=Count+What=birth (monoculture)
# Parent-Daughter Kin ID Commonality=2+Statistic=Count+What=birth (monoculture)
# Parent-Daughter Kin ID Commonality=0+Statistic=Frequency+What=birth (monoculture)
# Parent-Daughter Kin ID Commonality=1+Statistic=Frequency+What=birth (monoculture)
# Parent-Daughter Kin ID Commonality=2+Statistic=Frequency+What=birth (monoculture)
# Parent-Eliminated Kin ID Commonality=0+Statistic=Count+What=birth (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Statistic=Count+What=birth (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Statistic=Count+What=birth (monoculture)
# Parent-Eliminated Kin ID Commonality=0+Statistic=Frequency+What=birth (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Statistic=Frequency+What=birth (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Statistic=Frequency+What=birth (monoculture)
# Eliminated Cell Level 0 Peripherality=0+Statistic=Count+What=birth (monoculture)
# Eliminated Cell Level 0 Peripherality=1+Statistic=Count+What=birth (monoculture)
# Eliminated Cell Level 0 Peripherality=2+Statistic=Count+What=birth (monoculture)
# Eliminated Cell Level 0 Peripherality=3+Statistic=Count+What=birth (monoculture)
# Eliminated Cell Level 0 Peripherality=4+Statistic=Count+What=birth (monoculture)
# Eliminated Cell Level 0 Peripherality=0+Statistic=Frequency+What=birth (monoculture)
# Eliminated Cell Level 0 Peripherality=1+Statistic=Frequency+What=birth (monoculture)
# Eliminated Cell Level 0 Peripherality=2+Statistic=Frequency+What=birth (monoculture)
# Eliminated Cell Level 0 Peripherality=3+Statistic=Frequency+What=birth (monoculture)
# Eliminated Cell Level 0 Peripherality=4+Statistic=Frequency+What=birth (monoculture)
# Eliminated Cell Level 1 Peripherality=0+Statistic=Count+What=birth (monoculture)
# Eliminated Cell Level 1 Peripherality=1+Statistic=Count+What=birth (monoculture)
# Eliminated Cell Level 1 Peripherality=2+Statistic=Count+What=birth (monoculture)
# Eliminated Cell Level 1 Peripherality=3+Statistic=Count+What=birth (monoculture)
# Eliminated Cell Level 1 Peripherality=4+Statistic=Count+What=birth (monoculture)
# Eliminated Cell Level 1 Peripherality=0+Statistic=Frequency+What=birth (monoculture)
# Eliminated Cell Level 1 Peripherality=1+Statistic=Frequency+What=birth (monoculture)
# Eliminated Cell Level 1 Peripherality=2+Statistic=Frequency+What=birth (monoculture)
# Eliminated Cell Level 1 Peripherality=3+Statistic=Frequency+What=birth (monoculture)
# Eliminated Cell Level 1 Peripherality=4+Statistic=Frequency+What=birth (monoculture)
# Mean Fitness Differential Against Immediate Predecessor Population
# Median Fitness Differential Against Immediate Predecessor Population
# Fraction Immediate Predecessor Battles Won
# Immediate Predecessor Battle Null p-value
# a=credible_interval_lower_bound_idx+set_size=4
# a=most_credible_idx+set_size=4
# a=most_credible_likelihood+set_size=4
# a=credible_interval_upper_bound_idx+set_size=4
# a=credible_interval_lower_bound_idx+set_size=5
# a=most_credible_idx+set_size=5
# a=most_credible_likelihood+set_size=5
# a=credible_interval_upper_bound_idx+set_size=5
# Bucket
# Fitness Complexity
# Number Unique Module Expression Profiles
# Number Unique Module Regulation Profiles
# Num Instructions Executed per Live Cardinal-update
# Mean Resource Received Per Cell
# Resource Receiving Cell Fraction
# Fraction Deaths apoptosis
# Fraction Deaths elimination
# Nulliparous Fraction
# Mean Kin Group Size Level 0
# Mean Kin Group Size Level 1
# Expected Mutations
# Mutation Accumulation
# Elapsed Generations
# Selection Pressure
# % Generations Level 0
# % Generations Level 1
# % Generations Level 2
# Mean Mutations per Generation
# Fitness Complexity Delta
# Fitness Complexity Delta %
# Fitness Complexity Delta Sign
# Phenotype Complexity Delta
# Phenotype Complexity Delta %
# Phenotype Complexity Delta Sign
# Predecessor Battle Outcome
# Neutral Phenotypic Variation Under Mutation
# Fraction Phenotypic Variation That Is Neutral Under Mutation
# Num Less Fit Under State Exchanges
# Num Less Fit Under State Rotates
# Num Less Fit Under State Perturbation
# Cardinal Interface Complexity
# Cell Interface Complexity
# Fraction Neighbors Exactly Kin Level 1 (monoculture mean)
# Parent-Eliminated Kin ID Commonality>=1+Statistic=Frequency+What=birth (monoculture)
# Birth Conflict Ratio for Kin Commonality At Least 1
# Birth Conflict Ratio for Kin Commonality Exactly 1
# Birth Conflict Ratio for Kin Commonality Exactly 2
# Stint Decade
# Critical Fitness Complexity
# Interpolated Fitness Complexity
# Composite Fitness Complexity
# Composite Fitness Complexity Lower Bound
# Composite Fitness Complexity Upper Bound
# More Fit than Predecessor
# Less Fit than Predecessor
# Predecessor Fitness Differentiation
# Predecessor Fitness Neutrality
# Morph
# proc
# Lowest Num Stint Root IDs
# Lowest Root ID

# %% [markdown]
# ## Fitness Data

# %%
background_key = {
    "immediatepredecessor-simuls-dosecorrected-withbioticbackground-withmut"
        : "Prefatory",
    "immediatepredecessor-simuls-dosecorrected-withfuturebioticbackground-withmut"
        : "Contemporary",
    "immediatepredecessor-simuls-nobioticbackground-withmut"
        : "Without",
    "lowestroot-immediatepredecessor-battles"
        : "Without",
    "immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withbioticbackground-withmut"
        : "Prefatory\n(no diversity maint.)",
    "immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withfuturebioticbackground-withmut"
        : "Contemporary\n(no diversity maint.)",
    "immediatepredecessor-battles-dosecorrected-withbioticbackground-withmut"
        : "Prefatory",
    "immediatepredecessor-battles-dosecorrected-withfuturebioticbackground-withmut"
        : "Contemporary",
}

# %%
color_key = {
    'a' : 'tab:blue',
    'b' : 'tab:orange',
    'c' : 'tab:green',
    'd' : 'tab:red',
    'e' : 'tab:purple',
    'f' : 'tab:brown',
    'g' : 'tab:pink',
    'h' : 'tab:gray',
    'i' : 'tab:olive',
    'j' : 'tab:cyan',
}

# %%
morph_key = {
    row['Stint'] : row['Morph']
    for idx, row in df_morph.iterrows()
}

# %%
def subject_key(setup: str) -> str:
    if 'simul' in setup or 'competition' in setup:
        return 'Specimen'
    elif 'battle' in setup:
        return 'Population'
    else:
        assert False

# %%
dfs_fit = []
for setup in (
    "immediatepredecessor-simuls-dosecorrected-withbioticbackground-withmut",
    "immediatepredecessor-simuls-dosecorrected-withfuturebioticbackground-withmut",
    "immediatepredecessor-simuls-nobioticbackground-withmut",
    "lowestroot-immediatepredecessor-battles",
    "immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withbioticbackground-withmut",
    "immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withfuturebioticbackground-withmut",
    "immediatepredecessor-battles-dosecorrected-withbioticbackground-withmut",
    "immediatepredecessor-battles-dosecorrected-withfuturebioticbackground-withmut",
):
    print(setup)
    df_fit = pd.read_csv(
        f"https://prq49.s3.us-east-2.amazonaws.com/endeavor%3D16/{setup}/stage%3D2%2Bwhat%3Dcollated/a%3Dconcat%2Bhow%3Dmanual%2Bext%3D.csv",
    )
    df_fit["setup"] = setup
    if "Fitness Differential Focal" not in df_fit:
        df_fit["Fitness Differential Focal"] = df_fit["Fitness Differential"]
    if "Focal Prevalence" not in df_fit:
        df_fit["Focal Prevalence"] = df_fit["Prevalence"]
    if "Focal Abundance" not in df_fit:
        df_fit["Focal Abundance"] = df_fit["Abundance"]

    df_fit['Positive Fitness Differential Focal'] = df_fit['Fitness Differential Focal'] > 0

    dfs_fit.append(df_fit)
# Out:
# immediatepredecessor-simuls-dosecorrected-withbioticbackground-withmut
# immediatepredecessor-simuls-dosecorrected-withfuturebioticbackground-withmut
# immediatepredecessor-simuls-nobioticbackground-withmut
# lowestroot-immediatepredecessor-battles
# immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withbioticbackground-withmut
# immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withfuturebioticbackground-withmut
# immediatepredecessor-battles-dosecorrected-withbioticbackground-withmut
# immediatepredecessor-battles-dosecorrected-withfuturebioticbackground-withmut

# %%
df_fit = pd.concat(dfs_fit, ignore_index=True)
df_fit['Biotic Background'] = df_fit['setup'].apply(lambda setup: background_key[setup])
df_fit['Assay Subject'] = df_fit['setup'].apply(lambda setup: subject_key(setup))
df_fit['Assay Subject'] = df_fit['setup'].apply(lambda setup: subject_key(setup))

# %%
df_fit = df_fit[
    (df_fit["Root ID"] == 1)
    & (df_fit["Competition Stint"] > 0)
]

# %%
# adapted from https://stackoverflow.com/a/49601444
def lighten_color(color, amount=0.5):
    """
    Lightens the given color by multiplying (1-luminosity) by the given amount.
    Input can be matplotlib color string, hex string, or RGB tuple.

    Examples:
    >> lighten_color('g', 0.3)
    >> lighten_color('#F034A3', 0.6)
    >> lighten_color((.3,.55,.1), 0.5)
    """
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    r, g, b = mc.to_rgb(c)
    return r + amount * (1 - r), g + amount * (1 - g), b + amount * (1 - b)

# %%
df["Mutational Sensitivity"] = 1 - df["Fraction Mutations that are Deleterious"]

# %%
prev_stint = [  # from phylo
    0,  # 0
    1,  # 1
    2,  # 2
    2,  # 3
    3,  # 4
    3,  # 5
    3,  # 6
    6,  # 7
    6,  # 8
    5,  # 9
    9,  # 10
    10, # 11
    9,  # 12
    12,  # 13
    13,  # 14
    13,  # 15
    15,  # 16
    16,  # 17
    17,  # 18
    18,  # 19
    18,  # 20
    20,  # 21
    21,  # 22
    19,  # 23
    23,  # 24
    24,  # 25
    24,  # 26
    24,  # 27
    26,  # 28
    27,  # 29
    29,  # 30
    29,  # 31
    29,  # 32
    30,  # 33
    32,  # 34
    34,  # 35
    33,  # 36
    36,  # 37
    37,  # 38
    36,  # 39
    38,  # 40
    39,  # 41
    40,  # 42
    41,  # 43
    42,  # 44
    42,  # 45
    45,  # 46
    46,  # 47
    47,  # 48
    46,  # 49
    49,  # 50
    49,  # 51
    49,  # 52
    52,  # 53
    49,  # 54
    49,  # 55
    55,  # 56
    56,  # 57
    55,  # 58
    56,  # 59
    57,  # 60
    60,  # 61
    61,  # 62
    57,  # 63
    63,  # 64
    64,  # 65
    63,  # 66
    66,  # 67
    64,  # 68
    63,  # 69
    68,  # 70
    69,  # 71
    69,  # 72
    72,  # 73
    68,  # 74
    73,  # 75
    73,  # 76
    76,  # 77
    68,  # 78
    76,  # 79
    78,  # 80
    79,  # 81
    80,  # 82
    80,  # 83
    83,  # 84
    83,  # 85
    85,  # 86
    80,  # 87
    85,  # 88
    87,  # 89
    87,  # 90
    90,  # 91
    89,  # 92
    90,  # 93
    93,  # 94
    93,  # 95
    93,  # 96
    94,  # 97
    94,  # 98
    98,  # 99
    99, # 100
]
import numpy as np
prev_stint_np = np.array(prev_stint)

# %% [markdown]
# ## Plotting

# %%
data_df = df.sort_values(
    "Stint",
).loc[
    (
        (df["Series"] == 16005)
    ),
].sort_values("Stint")
data_df["prevcplx"] = data_df["Critical Fitness Complexity"].to_numpy()[
    prev_stint_np
]
data_df["prevphen"] = data_df["Cardinal Interface Complexity"].to_numpy()[
    prev_stint_np
]
data_df["prevsize"] = data_df['Num Instructions'].to_numpy()[
    prev_stint_np
]

data_df["Δ Genome Complexity"] = data_df["Critical Fitness Complexity"] - data_df["prevcplx"]
data_df["Δ Phenotype Complexity"] = data_df["Cardinal Interface Complexity"] - data_df["prevphen"]


data_df["Genome Complexity Increase"] = data_df["Critical Fitness Complexity"] - data_df["prevcplx"] > 0
data_df["Phenotype Complexity Increase"] = data_df["Cardinal Interface Complexity"] - data_df["prevphen"] > 0

data_df["Genome Complexity"] = data_df["Genome Complexity Increase"].map(
    {
        True: "Increase",
        False: "No\nIncrease",
    }
)

data_df["Phenotype Complexity"] = data_df["Phenotype Complexity Increase"].map(
    {
        True: "Increase",
        False: "No\nIncrease",
    }
)

data_df["Genome Size Increase"] = data_df["Num Instructions"] - data_df["prevsize"]
data_df["Genome Growth"] = data_df["Genome Size Increase"] > 0
data_df["Genome Expansion"] = data_df["Genome Growth"].map(
    {
        True: "Genome\nExpansion",
        False: "No Genome\nExpansion",
    },
)

data_df
# Out:
#                  Repro  Endeavor  Slurm Job ID  N_THREADS  RUN  RUN_UPDATES  \
# 5     XErLVfbqLT60JFeE        16      20670395          4    1            0
# 45    NvxfoVpRXCKuxye7        16      20672994          4    1            0
# 525   mzh5wPEvHyIYjQ3T        16      20681956          4    1            0
# 965   MeH88coMRwHapqYG        16      20691856          4    1            0
# 1405  Ni6qp1umTyXmhCLa        16      20705685          4    1            0
# ...                ...       ...           ...        ...  ...          ...
# 3885  0fGpqcwabVBHFesQ        16      22563551          4    1            0
# 3925  lsfTCcEePpfTBkZu        16      22569089          4    1            0
# 3965  2iWuQ4Xiga3AmLtL        16      22577898          4    1            0
# 4005  BB9KkPnSoj9qwQce        16      22586176          4    1            0
# 125   wrMyS2wFIvkGAkqy        16      22593414          4    1            0
#
#       RUN_SECONDS  MAIN_TIMEOUT_SECONDS  END_SNAPSHOT_TIMEOUT_SECONDS  \
# 5           10800                 13500                          1200
# 45          10800                 13500                          1200
# 525         10800                 13500                          1200
# 965         10800                 13500                          1200
# 1405        10800                 13500                          1200
# ...           ...                   ...                           ...
# 3885        10800                 13500                          1200
# 3925        10800                 13500                          1200
# 3965        10800                 13500                          1200
# 4005        10800                 13500                          1200
# 125         10800                 13500                          1200
#
#       LOG_FREQ  ...  prevphen  prevsize  Δ Genome Complexity  \
# 5           20  ...       3.0      94.0                 0.00
# 45          20  ...       2.0     127.0                 0.00
# 525         20  ...       5.0     280.0                 0.00
# 965         20  ...       5.0     280.0                -7.09
# 1405        20  ...       3.0     270.0                 4.91
# ...        ...  ...       ...       ...                  ...
# 3885        20  ...      12.0    1535.0                -6.83
# 3925        20  ...      11.0    1544.0                 2.42
# 3965        20  ...      11.0    1544.0                -4.98
# 4005        20  ...      14.0    1549.0                 3.98
# 125         20  ...      15.0    1540.0                -6.45
#
#       Δ Phenotype Complexity Genome Complexity Increase  \
# 5                        0.0                      False
# 45                       0.0                      False
# 525                      0.0                      False
# 965                     -2.0                      False
# 1405                     2.0                       True
# ...                      ...                        ...
# 3885                    -7.0                      False
# 3925                     1.0                       True
# 3965                     3.0                      False
# 4005                     1.0                       True
# 125                     -2.0                      False
#
#       Phenotype Complexity Increase  Genome Complexity  Genome Size Increase  \
# 5                             False       No\nIncrease                   0.0
# 45                            False       No\nIncrease                   0.0
# 525                           False       No\nIncrease                   0.0
# 965                           False       No\nIncrease                 -10.0
# 1405                           True           Increase                 -27.0
# ...                             ...                ...                   ...
# 3885                          False       No\nIncrease                  75.0
# 3925                           True           Increase                 -34.0
# 3965                           True       No\nIncrease                   5.0
# 4005                           True           Increase                  -9.0
# 125                           False       No\nIncrease                  28.0
#
#       Genome Growth      Genome Expansion
# 5             False  No Genome\nExpansion
# 45            False  No Genome\nExpansion
# 525           False  No Genome\nExpansion
# 965           False  No Genome\nExpansion
# 1405          False  No Genome\nExpansion
# ...             ...                   ...
# 3885           True     Genome\nExpansion
# 3925          False  No Genome\nExpansion
# 3965           True     Genome\nExpansion
# 4005          False  No Genome\nExpansion
# 125            True     Genome\nExpansion
#
# [101 rows x 3070 columns]

# %%
for subject, biotic_background in [
    ("Specimen", "Contemporary"),
    ("Specimen", "Prefatory"),
    ("Specimen", "Without"),
    ("Population", "Contemporary"),
    ("Population", "Prefatory"),
    ("Population", "Without"),
]:
    for test in "t", "mw":
        data_fit = df_fit.sort_values(
            "Competition Stint",
        ).loc[
            (
                # (df_fit["Competition Stint"] > 1)
                (df_fit["Assay Subject"] == subject)
                & (df_fit["Biotic Background"] == biotic_background)
            ),
        ].groupby(
            "Competition Stint",
        ).median(numeric_only=True).reset_index()
        data_fit

        data = data_df.merge(
            data_fit,
            left_on="Stint",
            right_on="Competition Stint",
            how="inner",
            suffixes=("", "_fit"),
        ).sort_values("Stint")

        data["Morph"] = data["Morph"].replace(
            {
                "a": 0,
                "b": 1,
                "c": 2,
                "d": 3,
                "e": 4,
                "f": 5,
                "g": 6,
                "h": 7,
                "i": 8,
                "j": 9,
            },
        )

        dx = data.loc[
            (data["Stint"] > 1)
        ].sort_values("Stint")

        from cliffs_delta import cliffs_delta
        from scipy import stats as scipy_stats

        with tp.teed(
            sns.violinplot,
            data=dx,
            x="Genome Expansion",
            y="Fitness Differential Focal",
            hue="Genome Expansion",
            split=True,
            gap=0.1,
            legend=False,
            palette="Pastel1",
            teeplot_subdir=teeplot_subdir,
            teeplot_outattrs={
                "subject": subject,
                "biotic_background": biotic_background,
                "test": test,
            },
        ) as teed:
            teed.collections[1].set_edgecolor('gainsboro')
            teed.collections[0].set_edgecolor('gainsboro')
            sns.stripplot(
                data=dx,
                x="Genome Expansion",
                y="Fitness Differential Focal",
                ax=teed,
                color="black",
                s=2,
            )
            if test == "mw":
                ptest = scipy_stats.mannwhitneyu(
                    dx.loc[dx["Genome Growth"], "Fitness Differential Focal"],
                    dx.loc[~dx["Genome Growth"], "Fitness Differential Focal"],
                )
            elif test == "t":
                ptest = scipy_stats.ttest_ind(
                    dx.loc[dx["Genome Growth"], "Fitness Differential Focal"],
                    dx.loc[~dx["Genome Growth"], "Fitness Differential Focal"],
                )
            else:
                assert False
            cliffd = cliffs_delta(
                dx.loc[dx["Genome Growth"], "Fitness Differential Focal"],
                dx.loc[~dx["Genome Growth"], "Fitness Differential Focal"],
            )[0]
            teed.annotate(
                text=f"p={ptest.pvalue:.2}\n δ={cliffd:.2f}",
                xy=(1, 0.1) if subject == "Specimen" else (0.45, 0.8),
                xycoords="axes fraction",
                ha="right",
                va="center",
                fontsize=10,
                # bbox=dict(boxstyle="round", fc="white", ec="gray", alpha=0.8),
            )
            teed.set_ylim(
                {
                    "Specimen": (-0.0003, 0.0003),
                    "Population": (-0.00015, 0.00025),
                }[subject]
            )
            teed.set_ylabel("Fitness Effect Size")
            teed.set_xlabel("")
            teed.figure.set_size_inches(2, 2)
            plt.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))
            teed.spines['top'].set_visible(False)
            teed.spines['right'].set_visible(False)
            teed.set_xticklabels(
                ["No Genome\nExpansion", "Genome\nExpansion"],
                rotation=15,
            )
# Out:
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-expansion+palette=pastel1+subject=Specimen+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-expansion+palette=pastel1+subject=Specimen+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-expansion+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-expansion+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-expansion+palette=pastel1+subject=Specimen+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-expansion+palette=pastel1+subject=Specimen+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-expansion+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-expansion+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-expansion+palette=pastel1+subject=Specimen+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-expansion+palette=pastel1+subject=Specimen+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-expansion+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-expansion+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-expansion+palette=pastel1+subject=Population+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-expansion+palette=pastel1+subject=Population+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-expansion+palette=pastel1+subject=Population+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-expansion+palette=pastel1+subject=Population+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-expansion+palette=pastel1+subject=Population+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-expansion+palette=pastel1+subject=Population+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-expansion+palette=pastel1+subject=Population+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-expansion+palette=pastel1+subject=Population+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-expansion+palette=pastel1+subject=Population+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-expansion+palette=pastel1+subject=Population+test=t+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png
# <ipython-input-29-b1cdc8803cfb>:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   teed.set_xticklabels(
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-expansion+palette=pastel1+subject=Population+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-expansion+palette=pastel1+subject=Population+test=mw+viz=violinplot+x=genome-expansion+y=fitness-differential-focal+ext=.png

# %%
for subject, biotic_background in [
    ("Specimen", "Contemporary"),
    ("Specimen", "Prefatory"),
    ("Specimen", "Without"),
    ("Population", "Contemporary"),
    ("Population", "Prefatory"),
    ("Population", "Without"),
]:
    for test in "t", "mw":
        data_fit = df_fit.sort_values(
            "Competition Stint",
        ).loc[
            (
                # (df_fit["Competition Stint"] > 1)
                (df_fit["Assay Subject"] == subject)
                & (df_fit["Biotic Background"] == biotic_background)
            ),
        ].groupby(
            "Competition Stint",
        ).median(numeric_only=True).reset_index()
        data_fit

        data = data_df.merge(
            data_fit,
            left_on="Stint",
            right_on="Competition Stint",
            how="inner",
            suffixes=("", "_fit"),
        ).sort_values("Stint")

        data["Morph"] = data["Morph"].replace(
            {
                "a": 0,
                "b": 1,
                "c": 2,
                "d": 3,
                "e": 4,
                "f": 5,
                "g": 6,
                "h": 7,
                "i": 8,
                "j": 9,
            },
        )

        dx = data.loc[
            (data["Stint"] > 1)
        ].sort_values("Stint")

        from cliffs_delta import cliffs_delta
        from scipy import stats as scipy_stats

        with tp.teed(
            sns.violinplot,
            data=dx,
            x="Genome Complexity",
            y="Fitness Differential Focal",
            hue="Genome Complexity",
            split=True,
            gap=0.1,
            legend=False,
            palette="Pastel1",
            teeplot_subdir=teeplot_subdir,
            teeplot_outattrs={
                "subject": subject,
                "biotic_background": biotic_background,
                "what": "genotype",
                "test": test,
            },
        ) as teed:
            teed.collections[1].set_edgecolor('gainsboro')
            teed.collections[0].set_edgecolor('gainsboro')
            sns.stripplot(
                data=dx,
                x="Genome Complexity",
                y="Fitness Differential Focal",
                ax=teed,
                color="black",
                s=2,
            )
            if test == "mw":
                ptest = scipy_stats.mannwhitneyu(
                    dx.loc[dx["Genome Complexity Increase"], "Fitness Differential Focal"],
                    dx.loc[~dx["Genome Complexity Increase"], "Fitness Differential Focal"],
                )
            elif test == "t":
                ptest = scipy_stats.ttest_ind(
                    dx.loc[dx["Genome Complexity Increase"], "Fitness Differential Focal"],
                    dx.loc[~dx["Genome Complexity Increase"], "Fitness Differential Focal"],
                )
            else:
                assert False
            cliffd = cliffs_delta(
                dx.loc[dx["Genome Complexity Increase"], "Fitness Differential Focal"],
                dx.loc[~dx["Genome Complexity Increase"], "Fitness Differential Focal"],
            )[0]
            teed.annotate(
                text=f"p={ptest.pvalue:.2}\n δ={cliffd:.2f}",
                xy=(1, 0.1) if subject == "Specimen" else (0.45, 0.8),
                xycoords="axes fraction",
                ha="right",
                va="center",
                fontsize=10,
                # bbox=dict(boxstyle="round", fc="white", ec="gray", alpha=0.8),
            )
            teed.set_ylim(
                {
                    "Specimen": (-0.0003, 0.0003),
                    "Population": None,
                }[subject]
            )
            teed.set_ylabel("Fitness Effect Size")
            teed.set_xlabel("Genome\n Complexity")
            teed.figure.set_size_inches(2, 2)
            plt.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))
            teed.spines['top'].set_visible(False)
            teed.spines['right'].set_visible(False)
# Out:
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=genome-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=genome-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=genome-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=genotype+x=genome-complexity+y=fitness-differential-focal+ext=.png

# %%
for subject, biotic_background in [
    ("Specimen", "Contemporary"),
    ("Specimen", "Prefatory"),
    ("Specimen", "Without"),
    ("Population", "Contemporary"),
    ("Population", "Prefatory"),
    ("Population", "Without"),
]:
    for test in "t", "mw":
        data_fit = df_fit.sort_values(
            "Competition Stint",
        ).loc[
            (
                # (df_fit["Competition Stint"] > 1)
                (df_fit["Assay Subject"] == subject)
                & (df_fit["Biotic Background"] == biotic_background)
            ),
        ].groupby(
            "Competition Stint",
        ).median(numeric_only=True).reset_index()
        data_fit

        data = data_df.merge(
            data_fit,
            left_on="Stint",
            right_on="Competition Stint",
            how="inner",
            suffixes=("", "_fit"),
        ).sort_values("Stint")

        data["Morph"] = data["Morph"].replace(
            {
                "a": 0,
                "b": 1,
                "c": 2,
                "d": 3,
                "e": 4,
                "f": 5,
                "g": 6,
                "h": 7,
                "i": 8,
                "j": 9,
            },
        )

        dx = data.loc[
            (data["Stint"] > 1)
        ].sort_values("Stint")

        from cliffs_delta import cliffs_delta
        from scipy import stats as scipy_stats

        with tp.teed(
            sns.violinplot,
            data=dx,
            x="Phenotype Complexity",
            y="Fitness Differential Focal",
            hue="Phenotype Complexity",
            split=True,
            gap=0.1,
            legend=False,
            palette="Pastel1",
            teeplot_subdir=teeplot_subdir,
            teeplot_outattrs={
                "subject": subject,
                "biotic_background": biotic_background,
                "what": "phenotype",
                "test": test,
            },
        ) as teed:
            teed.collections[1].set_edgecolor('gainsboro')
            teed.collections[0].set_edgecolor('gainsboro')
            sns.stripplot(
                data=dx,
                x="Phenotype Complexity",
                y="Fitness Differential Focal",
                ax=teed,
                color="black",
                s=2,
            )
            if test == "mw":
                ptest = scipy_stats.mannwhitneyu(
                    dx.loc[dx["Phenotype Complexity Increase"], "Fitness Differential Focal"],
                    dx.loc[~dx["Phenotype Complexity Increase"], "Fitness Differential Focal"],
                )
            elif test == "t":
                ptest = scipy_stats.ttest_ind(
                    dx.loc[dx["Phenotype Complexity Increase"], "Fitness Differential Focal"],
                    dx.loc[~dx["Phenotype Complexity Increase"], "Fitness Differential Focal"],
                )
            else:
                assert False
            cliffd = cliffs_delta(
                dx.loc[dx["Phenotype Complexity Increase"], "Fitness Differential Focal"],
                dx.loc[~dx["Phenotype Complexity Increase"], "Fitness Differential Focal"],
            )[0]
            teed.annotate(
                text=f"p={ptest.pvalue:.2}\n δ={cliffd:.2f}",
                xy=(1, 0.1) if subject == "Specimen" else (0.45, 0.8),
                xycoords="axes fraction",
                ha="right",
                va="center",
                fontsize=10,
                # bbox=dict(boxstyle="round", fc="white", ec="gray", alpha=0.8),
            )
            teed.set_ylim(
                {
                    "Specimen": (-0.0003, 0.0003),
                    "Population": None,
                }[subject]
            )
            teed.set_ylabel("Fitness Effect Size")
            teed.set_xlabel("Phenotype\n Complexity")
            teed.figure.set_size_inches(2, 2)
            plt.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))
            teed.spines['top'].set_visible(False)
            teed.spines['right'].set_visible(False)
# Out:
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=phenotype-complexity+palette=pastel1+subject=Specimen+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=phenotype-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=phenotype-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=phenotype-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Contemporary+hue=phenotype-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=phenotype-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=phenotype-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=phenotype-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Prefatory+hue=phenotype-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=phenotype-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=phenotype-complexity+palette=pastel1+subject=Population+test=t+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=phenotype-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+hue=phenotype-complexity+palette=pastel1+subject=Population+test=mw+viz=violinplot+what=phenotype+x=phenotype-complexity+y=fitness-differential-focal+ext=.png

# %%
dx = data_df.loc[
    (data_df["Stint"] > 1)
].sort_values("Stint")

from scipy import stats as scipy_stats

with tp.teed(
    sns.regplot,
    data=dx,
    x="Δ Genome Complexity",
    y="Δ Phenotype Complexity",
    scatter_kws={'s': 8, "alpha": 0.5},
    line_kws={'color': 'black', 'alpha': 0.5},
    teeplot_subdir=teeplot_subdir,
    teeplot_outattrs={
        "subject": subject,
        "biotic_background": biotic_background,
        "what": "phenotype",
        "test": test,
    },
) as teed:

    r, p = scipy_stats.pearsonr(
        dx["Δ Genome Complexity"],
        dx["Δ Phenotype Complexity"],
    )

    teed.annotate(
        text=f"r={r:.2f}\np={p:.1e}",
        xy=(1, 0.15),
        xycoords="axes fraction",
        ha="right",
        va="center",
        fontsize=10,
        # bbox=dict(boxstyle="round", fc="white", ec="gray", alpha=0.8),
    )
    teed.set_ylim(
        {
            "Specimen": (-0.0003, 0.0003),
            "Population": None,
        }[subject]
    )
    teed.figure.set_size_inches(2.5, 1.5)
    teed.spines['top'].set_visible(False)
    teed.spines['right'].set_visible(False)
    teed.set_ylabel("Δ Phenotype\nComplexity")
# Out:
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+subject=Population+test=mw+viz=regplot+what=phenotype+x=d-genome-complexity+y=d-phenotype-complexity+ext=.pdf
# teeplots/2025-09-05-genome-expansion-fitness/biotic_background=Without+subject=Population+test=mw+viz=regplot+what=phenotype+x=d-genome-complexity+y=d-phenotype-complexity+ext=.png
