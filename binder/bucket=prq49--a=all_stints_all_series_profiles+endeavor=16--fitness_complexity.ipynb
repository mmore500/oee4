# %%
import itertools as it

import boto3
import botocore
from iterdub import iterdub as ib
import matplotlib.pyplot as plt
import pandas as pd
from pandas.util import hash_pandas_object
from scipy import stats
import seaborn as sns
from teeplot import teeplot as tp

# %%
from dishpylib.pyhelpers import print_runtime

# %%
teeplot_subdir = "bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity"

# %%
print_runtime()
# Out:
# context: ci
# hostname: runnervmvatxw
# interpreter: 3.10.12 (main, Jan  8 2026, 06:52:19) [GCC 11.4.0]
# notebook name: bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity
# notebook path: /home/runner/work/oee4/oee4/binder/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity.ipynb
# revision: bdac574
# timestamp: 2026-01-22T15:37:53Z00:00
#
# IPython==7.16.1
# packaging==25.0
# <ipython-input-4-4d790cf6450f>:1: DeprecatedWarning: print_runtime is deprecated. use nbmetalog package instead
#   print_runtime()

# %%
def make_outattr_metadata(*args, **kwargs):
    return {}

# %% [markdown]
# # get data

# %%
s3_handle = boto3.resource(
    's3',
    region_name="us-east-2",
    config=botocore.config.Config(
        signature_version=botocore.UNSIGNED,
    ),
)
bucket_handle = s3_handle.Bucket('prq49')

series_profiles, = bucket_handle.objects.filter(
    Prefix=f'endeavor=16/series-profiles/stage=8+what=elaborated/',
)

# %%
df = pd.read_csv(
    f's3://prq49/{series_profiles.key}',
    compression='xz',
)
dfdigest = '{:x}'.format( hash_pandas_object( df ).sum() )
dfdigest
# Out:
# <ipython-input-7-747b1fe91af5>:1: DtypeWarning: Columns (2270,2277,2284,2285,2286,2287,2289,2290,2291,2292,2298,2299,2300,2301,2302,2308,2309,2310) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# '-1af9f0eb89153a8e'

# %%
for stint in df['Stint'].unique():
    exec(f'df{stint} = df[ df["Stint"] == {stint} ]')

# %%
dfm10 = df[ df['Stint'] % 10 == 0 ]

# %% [markdown]
# # how does fitness complexity change over time?

# %%
for what, y in it.product(
    (16005, 16018, 16021),
    (
        "Fitness Complexity",
        "Flagged Advantageous Sites",
    ),
):
    with tp.teed(
        sns.lineplot,
        data=dfm10,
        x="Stint",
        y=y,
        hue="Series",
        alpha=0.5,
        legend=False,
        lw=1,
        teeplot_outattrs={"what": what},
        teeplot_subdir=teeplot_subdir,
    ) as ax:
        ax.figure.set_size_inches(4.5, 1.5)
        sns.lineplot(
            data=dfm10[dfm10["Series"] == what],
            x="Stint",
            y=y,
            color="white",
            lw=5,
            alpha=0.8,
        )
        sns.lineplot(
            data=dfm10[dfm10["Series"] == what],
            x="Stint",
            y=y,
            color="tab:blue",
            lw=1.5,
        )
        sns.despine(ax=ax)
        ax.set_ylabel("Genotype\nComplexity")
# Out:
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16005+x=stint+y=fitness-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16005+x=stint+y=fitness-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16005+x=stint+y=flagged-advantageous-sites+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16005+x=stint+y=flagged-advantageous-sites+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16018+x=stint+y=fitness-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16018+x=stint+y=fitness-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16018+x=stint+y=flagged-advantageous-sites+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16018+x=stint+y=flagged-advantageous-sites+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16021+x=stint+y=fitness-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16021+x=stint+y=fitness-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16021+x=stint+y=flagged-advantageous-sites+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/hue=series+viz=lineplot+what=16021+x=stint+y=flagged-advantageous-sites+ext=.png

# %%
for what, x, how, inner in it.product(
    (16005, 16018, 16021),
    (
        "Fitness Complexity",
        "Flagged Advantageous Sites",
    ),
    (
        "mean",
        "median",
    ),
    (
        "box",
        None,
    ),
):
    y = "Cardinal Interface Complexity"
    data = getattr(
        dfm10.groupby(["Series"])[[x, y]], how
    )().reset_index()
    with tp.teed(
        sns.scatterplot,
        data=data,
        x=x,
        y=y,
        hue="Series",
        alpha=0.5,
        clip_on=False,
        legend=False,
        lw=1,
        teeplot_outattrs={"what": what, "how": how, "inner": inner},
        teeplot_subdir=teeplot_subdir,
    ) as ax:
        ax.figure.set_size_inches(1.5, 1.5)
        if inner == "box":
            sns.boxplot(
                data=data,
                x=4,
                y=y,
                ax=ax,
                color="lightgray",
                fliersize=0,
                native_scale=True,
                legend=False,
                width=1.2,
                whis=1.5,
            )
            ax.plot(
                [4, 4],
                [
                data[y].median(),
                    stats.iqr(data[y]) * 3 + data[y].quantile(0.75),
                ],
                ls=":",
                color="gray",
                lw=1,
                zorder=-10,
            )
            sns.boxplot(
                data=data,
                x=x,
                y=0.9,
                ax=ax,
                color="lightgray",
                fliersize=0,
                native_scale=True,
                orient="h",
                legend=False,
                width=0.5,
                whis=1.5,
            )
            ax.plot(
                [
                    data[x].median(),
                    stats.iqr(data[x]) * 3 + data[x].quantile(0.75),
                ],
                [0.9, 0.9],
                ls=":",
                color="gray",
                lw=1,
                zorder=-10,
            )
        sns.scatterplot(
            data=data[data["Series"] == what],
            x=x,
            y=y,
            style="Series",
            alpha=0.8,
            ax=ax,
            clip_on=False,
            color="white",
            legend=False,
            lw=2,
            markers=["o"],
        )
        sns.scatterplot(
            data=data[data["Series"] == what],
            x=x,
            y=y,
            ax=ax,
            style="Series",
            clip_on=False,
            color="tab:blue",
            legend=False,
            markers=["o"],
        )
        sns.scatterplot(
            data=data[data["Series"] == what],
            x=x,
            y=y,
            ax=ax,
            style="Series",
            clip_on=False,
            color="white",
            legend=False,
            markers=["o"],
            s=2,
        )
        ax.set_xlim(left=0)
        ax.set_ylim(bottom=0)
        sns.despine(ax=ax)
        ax.set_ylabel("Phenotype\nComplexity")
        ax.set_xlabel("Genotype Complexity      ")
# Out:
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16005+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16005+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16005+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16005+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16005+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16005+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16005+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16005+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16005+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16005+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16005+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16005+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16005+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16005+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16005+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16005+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16018+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16018+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16018+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16018+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16018+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16018+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16018+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16018+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16018+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16018+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16018+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16018+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16018+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16018+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16018+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16018+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16021+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16021+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16021+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16021+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16021+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16021+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16021+x=fitness-complexity+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16021+x=fitness-complexity+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16021+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=box+viz=scatterplot+what=16021+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16021+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=mean+hue=series+inner=None+viz=scatterplot+what=16021+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16021+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=box+viz=scatterplot+what=16021+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16021+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity/how=median+hue=series+inner=None+viz=scatterplot+what=16021+x=flagged-advantageous-sites+y=cardinal-interface-complexity+ext=.png

# %%
tp.tee(
    sns.lineplot,
    data=dfm10,
    x='Stint',
    y='Fitness Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=lineplot+x=stint+y=fitness-complexity+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=lineplot+x=stint+y=fitness-complexity+ext=.png
# <AxesSubplot:xlabel='Stint', ylabel='Fitness Complexity'>

# %%
def hline_swarmplot_boxplot(*args, **kwargs):
    plt.axhline(
        0,
        c='k',
        zorder=-1,
    )
    sns.swarmplot(
        *args,
        **kwargs,
        edgecolor='w',
        linewidth=0.5,
        s=4,
    )
    sns.boxplot(
        *args,
        **kwargs,
    )

tp.tee(
    hline_swarmplot_boxplot,
    data=dfm10,
    x='Stint',
    y='Fitness Complexity Delta',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=hline-swarmplot-boxplot+x=stint+y=fitness-complexity-delta+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=hline-swarmplot-boxplot+x=stint+y=fitness-complexity-delta+ext=.png

# %%
def hline_barplot(*args, **kwargs):
    plt.axhline(
        0,
        c='k',
        zorder=-1,
    )
    sns.barplot(
        *args,
        **kwargs,
    )

tp.tee(
    hline_barplot,
    data=dfm10,
    x='Stint',
    y='Fitness Complexity Delta',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=hline-barplot+x=stint+y=fitness-complexity-delta+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=hline-barplot+x=stint+y=fitness-complexity-delta+ext=.png

# %%
def swarmplot_boxplot(*args, **kwargs):
    sns.swarmplot(
        *args,
        **kwargs,
        edgecolor='w',
        linewidth=0.5,
        s=4,
    )
    sns.boxplot(
        *args,
        **kwargs,
    )

tp.tee(
    swarmplot_boxplot,
    data=dfm10,
    x='Stint',
    y='Fitness Complexity',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'identity',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 15.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# teeplots/bucket=prq49+endeavor=16+transform=identity+viz=swarmplot-boxplot+x=stint+y=fitness-complexity+ext=.pdf
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 15.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# teeplots/bucket=prq49+endeavor=16+transform=identity+viz=swarmplot-boxplot+x=stint+y=fitness-complexity+ext=.png

# %%
tp.tee(
    sns.lmplot,
    data=df40,
    x='Fitness Complexity',
    y='Fitness Complexity Delta Sign',
    logistic=True,
    truncate=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-40',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1395: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-40+viz=lmplot+x=fitness-complexity+y=fitness-complexity-delta-sign+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-40+viz=lmplot+x=fitness-complexity+y=fitness-complexity-delta-sign+ext=.png

# %%
def identityline_regplot(*args, **kwargs):
    sns.regplot(
        *args,
        **kwargs,
    )
    plt.plot(
        [0,30],
        [0,-30],
        c='k',
    )

tp.tee(
    identityline_regplot,
    data=df40,
    x='Fitness Complexity',
    y='Fitness Complexity Delta',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-40',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-40+viz=identityline-regplot+x=fitness-complexity+y=fitness-complexity-delta+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-40+viz=identityline-regplot+x=fitness-complexity+y=fitness-complexity-delta+ext=.png

# %% [markdown]
# # case study: series 16005

# %%
tp.tee(
    sns.lineplot,
    data=dfm10[ dfm10['Series'] == 16005 ],
    x='Stint',
    y='Fitness Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16005~filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~filter-Stint-mod10+viz=lineplot+x=stint+y=fitness-complexity+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~filter-Stint-mod10+viz=lineplot+x=stint+y=fitness-complexity+ext=.png
# <AxesSubplot:xlabel='Stint', ylabel='Fitness Complexity'>

# %% [markdown]
# # case study: series 16021

# %%
tp.tee(
    sns.lineplot,
    data=dfm10[ dfm10['Series'] == 16021 ],
    x='Stint',
    y='Fitness Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16021~filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16021~filter-Stint-mod10+viz=lineplot+x=stint+y=fitness-complexity+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16021~filter-Stint-mod10+viz=lineplot+x=stint+y=fitness-complexity+ext=.png
# <AxesSubplot:xlabel='Stint', ylabel='Fitness Complexity'>

# %% [markdown]
# # case study: series 16018

# %%
tp.tee(
    sns.lineplot,
    data=dfm10[ dfm10['Series'] == 16018 ],
    x='Stint',
    y='Fitness Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16018~filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16018~filter-Stint-mod10+viz=lineplot+x=stint+y=fitness-complexity+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16018~filter-Stint-mod10+viz=lineplot+x=stint+y=fitness-complexity+ext=.png
# <AxesSubplot:xlabel='Stint', ylabel='Fitness Complexity'>
