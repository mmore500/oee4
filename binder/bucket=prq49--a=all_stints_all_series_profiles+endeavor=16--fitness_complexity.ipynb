# %%
import itertools as it

import boto3
import botocore
from iterdub import iterdub as ib
import matplotlib.pyplot as plt
import pandas as pd
from pandas.util import hash_pandas_object
from scipy import stats
import seaborn as sns
from teeplot import teeplot as tp

# %%
from dishpylib.pyhelpers import print_runtime

# %%
teeplot_subdir = "bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--fitness_complexity"

# %%
print_runtime()

# %%
def make_outattr_metadata(*args, **kwargs):
    return {}

# %% [markdown]
# # get data

# %%
s3_handle = boto3.resource(
    's3',
    region_name="us-east-2",
    config=botocore.config.Config(
        signature_version=botocore.UNSIGNED,
    ),
)
bucket_handle = s3_handle.Bucket('prq49')

series_profiles, = bucket_handle.objects.filter(
    Prefix=f'endeavor=16/series-profiles/stage=8+what=elaborated/',
)

# %%
df = pd.read_csv(
    f's3://prq49/{series_profiles.key}',
    compression='xz',
)
dfdigest = '{:x}'.format( hash_pandas_object( df ).sum() )
dfdigest

# %%
for stint in df['Stint'].unique():
    exec(f'df{stint} = df[ df["Stint"] == {stint} ]')

# %%
dfm10 = df[ df['Stint'] % 10 == 0 ]

# %% [markdown]
# # how does fitness complexity change over time?

# %%
for what, y in it.product(
    (16005, 16018, 16021),
    (
        "Fitness Complexity",
        "Flagged Advantageous Sites",
    ),
):
    with tp.teed(
        sns.lineplot,
        data=dfm10,
        x="Stint",
        y=y,
        hue="Series",
        alpha=0.5,
        legend=False,
        lw=1,
        teeplot_outattrs={"what": what},
        teeplot_subdir=teeplot_subdir,
    ) as ax:
        ax.figure.set_size_inches(4.5, 1.5)
        sns.lineplot(
            data=dfm10[dfm10["Series"] == what],
            x="Stint",
            y=y,
            color="white",
            lw=5,
            alpha=0.8,
        )
        sns.lineplot(
            data=dfm10[dfm10["Series"] == what],
            x="Stint",
            y=y,
            color="tab:blue",
            lw=1.5,
        )
        sns.despine(ax=ax)
        ax.set_ylabel("Genotype\nComplexity")
        ax.set_xlabel("Transfer Round")

# %% [markdown]
# # case study: series 16005, morph-annotated (panel 2a, genotype complexity)

# %%
from io import StringIO

# morph classifications for case study series 16005, transfer rounds 0-100
# (verbatim from binder/2026-01-30-simple-keyfig.ipynb)
morph_csv = StringIO(
    """Stint,Morph,Series
0,a,16005
1,b,16005
2,c,16005
3,b,16005
4,b,16005
5,b,16005
6,b,16005
7,b,16005
8,b,16005
9,b,16005
10,b,16005
11,b,16005
12,b,16005
13,b,16005
14,d,16005
15,e,16005
16,e,16005
17,e,16005
18,e,16005
19,e,16005
20,e,16005
21,e,16005
22,e,16005
23,e,16005
24,e,16005
25,e,16005
26,b,16005
27,e,16005
28,b,16005
29,e,16005
30,e,16005
31,e,16005
32,e,16005
33,e,16005
34,e,16005
35,e,16005
36,e,16005
37,e,16005
38,e,16005
39,f,16005
40,e,16005
41,e,16005
42,e,16005
43,e,16005
44,e,16005
45,g,16005
46,g,16005
47,g,16005
48,g,16005
49,g,16005
50,g,16005
51,g,16005
52,g,16005
53,e,16005
54,g,16005
55,g,16005
56,g,16005
57,g,16005
58,g,16005
59,h,16005
60,g,16005
61,e,16005
62,g,16005
63,g,16005
64,e,16005
65,e,16005
66,g,16005
67,g,16005
68,e,16005
69,g,16005
70,e,16005
71,e,16005
72,e,16005
73,g,16005
74,i,16005
75,i,16005
76,g,16005
77,i,16005
78,e,16005
79,g,16005
80,e,16005
81,e,16005
82,e,16005
83,e,16005
84,e,16005
85,e,16005
86,e,16005
87,e,16005
88,e,16005
89,g,16005
90,g,16005
91,e,16005
92,i,16005
93,e,16005
94,e,16005
95,b,16005
96,b,16005
97,h,16005
98,e,16005
99,e,16005
100,j,16005
"""
)
df_morph = pd.read_csv(morph_csv)

# morph j's color, matching matplotlib's tab:cyan
# (verbatim from binder/2026-01-30-simple-keyfig.ipynb)
morph_j_color = "tab:cyan"


# adapted from binder/2026-01-30-simple-keyfig.ipynb "letterscatter":
# draws a black-outlined, colored circle with the morph letter in white.
# non-j morphs are grayed out so only the case-study's own morph (j)
# stands out; markers sit above the line, connected by a stem, at every
# sampled (mod-10) transfer round except round 0. A morph's first
# appearance is drawn at full strength; later recurrences of that same
# morph are faded to match the gray "morph" caption text, which is only
# shown above morph j.
def morph_novelty_markers(*, ax, data, x, y):
    data = data.sort_values(x)
    data = data[data[x] != 0]

    ylo, yhi = ax.get_ylim()
    span = yhi - ylo
    stem = 0.2 * span
    y_off = f"{y} (offset)"
    data = data.assign(**{y_off: data[y] + stem})

    # raise transfer round 10's marker to match morph e's height, so it
    # isn't crowded down near the noisy low-value region of the curve
    e_height = data.loc[data["Morph"] == "e", y_off].iloc[0]
    data.loc[data[x] == 10, y_off] = e_height

    seen = set()
    is_first = []
    for morph in data["Morph"]:
        is_first.append(morph not in seen)
        seen.add(morph)
    data = data.assign(is_first=is_first)

    # stems sit above the line's white halo but below the blue line
    # itself, so they read as emerging from beneath the highlighted curve
    halo_zorder = ax.lines[-2].get_zorder()
    blue_zorder = ax.lines[-1].get_zorder()
    stem_zorder = (halo_zorder + blue_zorder) / 2

    def draw_markers(group, outline, fill, letter):
        if group.empty:
            return
        for _, row in group.iterrows():
            ax.plot(
                [row[x], row[x]],
                [row[y], row[y_off]],
                color=outline,
                lw=0.8,
                zorder=stem_zorder,
            )
        palette = {
            morph: (morph_j_color if morph == "j" else fill)
            for morph in group["Morph"].unique()
        }
        sns.scatterplot(
            data=group, x=x, y=y_off,
            color=outline, edgecolor=outline, s=200, legend=False, zorder=5, ax=ax,
        )
        sns.scatterplot(
            data=group, x=x, y=y_off, hue="Morph", palette=palette,
            edgecolor=None, s=120, legend=False, zorder=6, ax=ax,
        )
        sns.scatterplot(
            data=group, x=x, y=y_off, color=letter, style="Morph",
            markers={
                phen: f"$\mathrm{{{phen}}}$"
                for phen in group["Morph"].unique()
            },
            legend=False, zorder=7, ax=ax,
        )

    draw_markers(data[data["is_first"]], outline="k", fill="gray", letter="w")
    draw_markers(
        data[~data["is_first"]], outline="0.75", fill="0.85", letter="0.5"
    )

    # faint, vertical "morph" caption, centered above the morph j marker
    label_gap = 0.14 * span
    for _, row in data[data["Morph"] == "j"].iterrows():
        ax.text(
            row[x], row[y_off] + label_gap,
            "morph",
            color="0.65",
            fontsize=6,
            rotation=90,
            ha="center",
            va="bottom",
            zorder=8,
        )

    top = data[y_off].max() + label_gap + 0.16 * span
    ax.set_ylim(ylo, max(yhi, top))

# %%
what, y = 16005, "Flagged Advantageous Sites"
data_what = dfm10[dfm10["Series"] == what]
data_morph = pd.merge(data_what, df_morph, on=["Stint", "Series"], how="inner")

with tp.teed(
    sns.lineplot,
    data=dfm10,
    x="Stint",
    y=y,
    hue="Series",
    alpha=0.5,
    legend=False,
    lw=1,
    teeplot_outattrs={"what": what, "annot": "morph"},
    teeplot_subdir=teeplot_subdir,
) as ax:
    ax.figure.set_size_inches(4.5, 1.5)
    sns.lineplot(
        data=data_what,
        x="Stint",
        y=y,
        color="white",
        lw=5,
        alpha=0.8,
        zorder=2,
    )
    sns.lineplot(
        data=data_what,
        x="Stint",
        y=y,
        color="tab:blue",
        lw=1.5,
        zorder=3,
    )
    morph_novelty_markers(ax=ax, data=data_morph, x="Stint", y=y)
    sns.despine(ax=ax)
    ax.set_ylabel("Genotype\nComplexity")
    ax.set_xlabel("Transfer Round")

# %%
for what, x, how, inner, iqr in it.product(
    (16005, 16018, 16021),
    (
        "Fitness Complexity",
        "Flagged Advantageous Sites",
    ),
    (
        "mean",
        "median",
    ),
    (
        "box",
        None,
    ),
    (
        "shade",
        None,
    ),
):
    y = "Cardinal Interface Complexity"
    data = getattr(
        dfm10.groupby(["Series"])[[x, y]], how
    )().reset_index()
    with tp.teed(
        sns.scatterplot,
        data=data,
        x=x,
        y=y,
        hue="Series",
        alpha=0.5,
        clip_on=False,
        legend=False,
        lw=1,
        teeplot_outattrs={
            "what": what, "how": how, "inner": inner, "iqr": iqr
        },
        teeplot_subdir=teeplot_subdir,
    ) as ax:
        ax.figure.set_size_inches(1.5, 1.5)
        xlim, ylim = ax.get_xlim()[1], ax.get_ylim()[1]

        if iqr == "shade":
            q3_x = stats.iqr(data[x]) * 3 + data[x].quantile(0.75)
            q3_y = stats.iqr(data[y]) * 3 + data[y].quantile(0.75)

            # Shade area where x > 3x IQR (vertical span)
            ax.axvspan(
                q3_x,
                ax.get_xlim()[1] * 1.1,
                color="k",
                alpha=0.1,
                zorder=-20,
                linewidth=0
            )
            # Annotation for X outlier region
            ax.text(
                q3_x * 1.015,
                q3_y * 0.5,
                r"$>3\times$ IQR",
                color="k",
                fontsize=7,
                ha="left",
                va="center",
                rotation=90,
            )

            # Shade area where y > 3x IQR (horizontal span)
            ax.axhspan(
                q3_y,
                ax.get_ylim()[1] * 1.1,
                color="k",
                alpha=0.1,
                zorder=-20,
                linewidth=0
            )
            # Annotation for Y outlier region
            ax.text(
                q3_x * 0.5,
                q3_y,
                r"$>3\times$ IQR",
                color="k",
                fontsize=7,
                ha="center",
                va="bottom",
            )

        if inner == "box":
            sns.boxplot(
                data=data,
                x=4,
                y=y,
                ax=ax,
                color="lightgray",
                fliersize=0,
                native_scale=True,
                legend=False,
                width=1.2,
                whis=1.5,
            )
            ax.plot(
                [4, 4],
                [
                   data[y].median(),
                    stats.iqr(data[y]) * 3 + data[y].quantile(0.75),
                ],
                ls=":",
                color="gray",
                lw=1,
                zorder=-10,
            )
            sns.boxplot(
                data=data,
                x=x,
                y=0.9,
                ax=ax,
                color="lightgray",
                fliersize=0,
                native_scale=True,
                orient="h",
                legend=False,
                width=0.5,
                whis=1.5,
            )
            ax.plot(
                [
                    data[x].median(),
                    stats.iqr(data[x]) * 3 + data[x].quantile(0.75),
                ],
                [0.9, 0.9],
                ls=":",
                color="gray",
                lw=1,
                zorder=-10,
            )
        sns.scatterplot(
            data=data[data["Series"] == what],
            x=x,
            y=y,
            style="Series",
            alpha=0.8,
            ax=ax,
            clip_on=False,
            color="white",
            legend=False,
            lw=2,
            markers=["o"],
        )
        sns.scatterplot(
            data=data[data["Series"] == what],
            x=x,
            y=y,
            ax=ax,
            style="Series",
            clip_on=False,
            color="tab:blue",
            legend=False,
            markers=["o"],
        )
        sns.scatterplot(
            data=data[data["Series"] == what],
            x=x,
            y=y,
            ax=ax,
            style="Series",
            clip_on=False,
            color="white",
            legend=False,
            markers=["o"],
            s=2,
        )
        ax.set_xlim(left=0, right=xlim)
        ax.set_ylim(bottom=0, top=ylim)
        sns.despine(ax=ax)
        ax.set_ylabel("Phenotype\nComplexity")
        ax.set_xlabel("Genotype Complexity      ")

# %%
with tp.teed(
    sns.lineplot,
    data=dfm10,
    x='Stint',
    y='Fitness Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
) as ax:
    ax.set_xlabel("Transfer Round")

# %%
def hline_swarmplot_boxplot(*args, **kwargs):
    plt.axhline(
        0,
        c='k',
        zorder=-1,
    )
    sns.swarmplot(
        *args,
        **kwargs,
        edgecolor='w',
        linewidth=0.5,
        s=4,
    )
    sns.boxplot(
        *args,
        **kwargs,
    )

with tp.teed(
    hline_swarmplot_boxplot,
    data=dfm10,
    x='Stint',
    y='Fitness Complexity Delta',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
) as ax:
    ax.set_xlabel("Transfer Round")

# %%
def hline_barplot(*args, **kwargs):
    plt.axhline(
        0,
        c='k',
        zorder=-1,
    )
    sns.barplot(
        *args,
        **kwargs,
    )

with tp.teed(
    hline_barplot,
    data=dfm10,
    x='Stint',
    y='Fitness Complexity Delta',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
) as ax:
    ax.set_xlabel("Transfer Round")

# %%
def swarmplot_boxplot(*args, **kwargs):
    sns.swarmplot(
        *args,
        **kwargs,
        edgecolor='w',
        linewidth=0.5,
        s=4,
    )
    sns.boxplot(
        *args,
        **kwargs,
    )

with tp.teed(
    swarmplot_boxplot,
    data=dfm10,
    x='Stint',
    y='Fitness Complexity',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'identity',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
) as ax:
    ax.set_xlabel("Transfer Round")

# %%
tp.tee(
    sns.lmplot,
    data=df40,
    x='Fitness Complexity',
    y='Fitness Complexity Delta Sign',
    logistic=True,
    truncate=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-40',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)

# %%
def identityline_regplot(*args, **kwargs):
    sns.regplot(
        *args,
        **kwargs,
    )
    plt.plot(
        [0,30],
        [0,-30],
        c='k',
    )

tp.tee(
    identityline_regplot,
    data=df40,
    x='Fitness Complexity',
    y='Fitness Complexity Delta',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-40',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)

# %% [markdown]
# # case study: series 16005

# %%
with tp.teed(
    sns.lineplot,
    data=dfm10[ dfm10['Series'] == 16005 ],
    x='Stint',
    y='Fitness Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16005~filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
) as ax:
    ax.set_xlabel("Transfer Round")

# %% [markdown]
# # case study: series 16021

# %%
with tp.teed(
    sns.lineplot,
    data=dfm10[ dfm10['Series'] == 16021 ],
    x='Stint',
    y='Fitness Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16021~filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
) as ax:
    ax.set_xlabel("Transfer Round")

# %% [markdown]
# # case study: series 16018

# %%
with tp.teed(
    sns.lineplot,
    data=dfm10[ dfm10['Series'] == 16018 ],
    x='Stint',
    y='Fitness Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16018~filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
) as ax:
    ax.set_xlabel("Transfer Round")

# %% [markdown]
# ## Correlation with Phenotype Complexity

# %%
data = dfm10[
    dfm10["Stint"].isin(range(10, 101, 10))
].groupby(
    ["Series"]
)[
    ["Flagged Advantageous Sites", "Cardinal Interface Complexity"]
].mean().reset_index()
with tp.teed(
    sns.lmplot,
    data=data,
    x="Flagged Advantageous Sites",
    y="Cardinal Interface Complexity",
    height=2,
    aspect=1,
    scatter_kws={"alpha": 0.5, "s": 10},
    line_kws={"lw": 1},
    teeplot_outattrs={
        **{
            'bucket': ib.dub(df['Bucket']),
            'endeavor': ib.dub(df['Endeavor'].astype(int)),
            'transform': 'filter-Stint-mod10',
            '_dfdigest': dfdigest,
        },
        **make_outattr_metadata(),
    },
    teeplot_subdir=teeplot_subdir,
) as g:
    g.set_axis_labels("Genotype Complexity", "Phenotype Complexity")

stats.linregress(
    data["Flagged Advantageous Sites"],
    data["Cardinal Interface Complexity"],
)
