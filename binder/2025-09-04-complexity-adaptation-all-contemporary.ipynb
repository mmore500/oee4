# %%
# %load_ext watermark

# %%
import boto3
import botocore
from io import StringIO
from iterdub import iterdub as ib
from iterpop import iterpop as ip
from matplotlib import pyplot as plt
import pandas as pd
from pandas.util import hash_pandas_object
import re
import seaborn as sns
import statsmodels.api as sm
from teeplot import teeplot as tp

# %%
import os

from IPython.display import display
import seaborn as sns
from teeplot import teeplot as tp

# from dishpylib.pyhelpers import make_outattr_metadata
# from dishpylib.pyhelpers import print_runtime

# %%
# %watermark -diwmuv -iv
# Out:
# Last updated: 2026-08-15T01:46:32.831785+00:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 7.16.1
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.8.0-1064-azure
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
# botocore   : 1.17.44
# iterdub    : 0.2.0
# boto3      : 1.14.44
# pandas     : 1.4.4
# matplotlib : 3.5.3
# seaborn    : 0.13.2
# teeplot    : 1.4.2
# re         : 2.2.1
# statsmodels: 0.13.5
# iterpop    : 0.3.4
#
# Watermark: 2.4.3

# %%
teeplot_subdir = os.environ.get(
    "NOTEBOOK_NAME", "2025-09-04-complexity-adaptation-contemporary"
)
teeplot_subdir
# Out:
# '2025-09-04-complexity-adaptation-all-contemporary'

# %% [markdown]
# # get data

# %%
s3_handle = boto3.resource(
    's3',
    region_name="us-east-2",
    config=botocore.config.Config(
        signature_version=botocore.UNSIGNED,
    ),
)
bucket_handle = s3_handle.Bucket('prq49')

series_profiles, = bucket_handle.objects.filter(
    Prefix=f'endeavor=16/series-profiles/stage=8+what=elaborated/',
)

# %%
df = pd.read_csv(
    f's3://prq49/{series_profiles.key}',
    compression='xz',
)
dfdigest = '{:x}'.format(hash_pandas_object( df ).sum())
dfdigest
# Out:
# <ipython-input-7-06b399353b17>:1: DtypeWarning: Columns (286,293,300,301,302,303,305,306,307,308,314,315,316,317,318,324,325,326) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# '-2cf7ba7a12df2efc'

# %% [markdown]
# # set up graphing utilities

# %%
def letterscatter(*,data,x,y,cat):
    sns.scatterplot(
        data=data,
        x=x,
        y=y,
        color='k',
        edgecolor='k',
        s=200,
    )
    sns.scatterplot(
        data=data,
        x=x,
        y=y,
        hue=cat,
        edgecolor=None,
        s=120,
    )
    sns.scatterplot(
        data=data,
        x=x,
        y=y,
        color='w',
        style=cat,
        markers={
            phen : f'$\mathrm{{{phen}}}$'
            for phen in data[cat].unique()
        },
        legend=False,
    )
    plt.legend(
        bbox_to_anchor=(1.01, 1),
        borderaxespad=0,
        title='Morph',
        frameon=False,
    )

# %%
def letterscatter_vline(*args, **kwargs):
    letterscatter(*args, **kwargs)
    plt.axvline(15,zorder=-2,c='k',ls=':')
    plt.axvline(45,zorder=-2,c='k',ls='--')

# %%
def letterscatter_vline_interpolationmissing(*args, **kwargs):
    letterscatter_vline(*args, **kwargs)

    for stint in dfx[ dfx['a=most_credible_idx+set_size=1'].isnull() ]['Stint']:
        plt.axvline(stint, c='gray', zorder=-2, alpha=0.5)

# %% [markdown]
# # preprocess data

# %%
morph_csv = StringIO('''Stint,Morph,Series
0,a,16005
1,b,16005
2,c,16005
3,b,16005
4,b,16005
5,b,16005
6,b,16005
7,b,16005
8,b,16005
9,b,16005
10,b,16005
0,2,96,16005,16,12634
0,3,96,16005,11,12634
0,0,97,16005,10,12634
0,1,97,16005,10,12634
0,2,97,16005,15,12634
0,3,97,16005,11,12634
0,0,98,16005,17,12634
0,1,98,16005,17,12634
0,2,98,16005,21,12634
0,3,98,16005,16,12634
0,0,99,16005,19,12634
0,1,99,16005,15,12634
0,2,99,16005,21,12634
0,3,99,16005,15,12634
0,0,9,16005,6,12634
0,1,9,16005,5,12634
0,2,9,16005,3,12634
0,3,9,16005,5,12634
''')

df_lowestroot_phylo = pd.read_csv(lowestroot_phylo_csv).groupby([
    'Series',
    'Stint',
]).mean().reset_index()

# %%
df = pd.merge(
    df,
    df_lowestroot_phylo,
    on=['Stint', 'Series'],
    how='outer',
)

# %%
dfm10 = df[ df['Stint'] % 10 == 0 ]

# %%
dfx = df[ df['Series'] == 16005 ].sort_values('Morph')

# %%
for col in df.columns:
    print(col)
# Out:
# Repro
# Endeavor
# Slurm Job ID
# N_THREADS
# RUN
# RUN_UPDATES
# RUN_SECONDS
# MAIN_TIMEOUT_SECONDS
# END_SNAPSHOT_TIMEOUT_SECONDS
# LOG_FREQ
# ASYNCHRONOUS
# SYNC_FREQ_MILLISECONDS
# RNG_PRESEED
# THROW_ON_EXTINCTION
# RUN_SLUG
# PHENOTYPIC_DIVERGENCE_N_UPDATES
# PHENOTYPIC_DIVERGENCE_N_CELLS
# STINT
# SERIES
# REPLICATE
# TREATMENT
# SEED_FILL_FRACTION
# GENESIS
# N_CELLS
# WEAK_SCALING
# N_DIMS
# GROUP_EXPIRATION_DURATIONS
# CELL_AGE_DURATION
# MIN_START_RESOURCE
# MAX_START_RESOURCE
# RESOURCE_DECAY
# APOP_RECOVERY_FRAC
# SPAWN_DEFENSE_COST
# BASE_HARVEST_RATE
# COLLECTIVE_HARVEST_RATE
# OPTIMAL_QUORUM_COUNT
# P_SET_QUORUM_BIT
# QUORUM_CAP
# P_QUORUM_CAP_KILL
# PROGRAM_START_SIZE
# PROGRAM_MAX_SIZE
# MUTATION_RATE
# POINT_MUTATION_RATE
# SEQUENCE_DEFECT_RATE
# MINOR_SEQUENCE_MUTATION_BOUND
# SEVERE_SEQUENCE_MUTATION_RATE
# HARDWARE_EXECUTION_ROUNDS
# HARDWARE_EXECUTION_CYCLES
# CONTROLLER_MAPPED_STATE_DEFECT_RATE
# APOPTOSIS_SERVICE_FREQUENCY
# BIRTH_SETUP_SERVICE_FREQUENCY
# CELL_AGE_SERVICE_FREQUENCY
# CONDUIT_FLUSH_SERVICE_FREQUENCY
# COLLECTIVE_HARVESTING_SERVICE_FREQUENCY
# CPU_EXECUTION_SERVICE_FREQUENCY
# GROUP_EXPIRATION_SERVICE_FREQUENCY
# RUNNING_LOG_PURGE_SERVICE_FREQUENCY
# DIVERSITY_MAINTENANCE_SERVICE_FREQUENCY
# DIVERSITY_MAINTENANCE_PREVALENCE
# STINT_DIVERSITY_MAINTENANCE_SERVICE_FREQUENCY
# STINT_DIVERSITY_MAINTENANCE_PREVALENCE
# DECAY_TO_BASELINE_SERVICE_FREQUENCY
# EPOCH_ADVANCE_SERVICE_FREQUENCY
# EVENT_LAUNCHING_SERVICE_FREQUENCY
# INTERMITTENT_CPU_RESET_SERVICE_FREQUENCY
# INTERMITTENT_STATE_PERTURB_SERVICES_FREQUENCY
# INTER_MESSAGE_COUNTER_CLEAR_SERVICE_FREQUENCY
# INTER_MESSAGE_LAUNCHING_SERVICE_FREQUENCY
# INTRA_MESSAGE_LAUNCHING_SERVICE_FREQUENCY
# STATE_OUTPUT_PUT_SERVICE_FREQUENCY
# PUSH_SERVICE_FREQUENCY
# QUORUM_CAP_SERVICE_FREQUENCY
# QUORUM_SERVICE_FREQUENCY
# RESOURCE_DECAY_SERVICE_FREQUENCY
# RESOURCE_HARVESTING_SERVICE_FREQUENCY
# RESOURCE_INPUT_JUMP_SERVICE_FREQUENCY
# RESOURCE_RECEIVING_SERVICE_FREQUENCY
# RESOURCE_SENDING_SERVICE_FREQUENCY
# SPAWN_SENDING_SERVICE_FREQUENCY
# STATE_INPUT_JUMP_SERVICE_FREQUENCY
# CONTROLLER_MAPPED_STATE_NOISE_SERVICE_FREQUENCY
# PHENOTYPE_EQUIVALENT_NOPOUT
# BATTLESHIP_PHENOTYPE_EQUIVALENT_NOPOUT
# JENGA_PHENOTYPE_EQUIVALENT_NOPOUT
# JENGA_NOP_OUT_SAVE_PROGRESS_AND_QUIT_SECONDS
# TEST_INTERROOT_PHENOTYPE_DIFFERENTIATION
# ALL_DRAWINGS_WRITE
# DATA_DUMP
# RUNNINGLOGS_DUMP
# CENSUS_WRITE
# ARTIFACTS_DUMP
# BENCHMARKING_DUMP
# ROOT_ABUNDANCES_FREQ
# ABORT_IF_COALESCENT_FREQ
# ABORT_IF_EXTINCT_FREQ
# ABORT_AT_LIVE_CELL_FRACTION
# REGULATION_VIZ_CLAMP
# RUNNING_LOG_DURATION
# SELECTED_DRAWINGS_FREQ
# DRAWING_WIDTH_PX
# DRAWING_HEIGHT_PX
# SELECTED_DRAWINGS
# ANIMATE_FRAMES
# VIDEO_FPS
# VIDEO_MAX_FRAMES
# Series
# Stint
# Stint_x
# Mean Inter-Strain Fitness Differential
# Stint_y
# Fraction Inter-Strain Competitions Won
# Inter-Strain Competition Null p-value
# Flagged Advantageous Sites
# Flagged Deleterious Sites
# H_0 Advantageous Site Flags
# H_0 Deleterious Site Flags
# Estimated True Advantageous Sites
# Estimated True Deleterious Sites
# Num More Fit Under Extrospective State Rotates @ Intermittent P 1
# Num Less Fit Under Extrospective State Rotates @ Intermittent P 1
# Fraction Extrospective State Rotates that are Advantageous @ Intermittent P 1
# Fraction Extrospective State Rotates that are Deleterious @ Intermittent P 1
# Mean Extrospective State Rotate Fitness Differential @ Intermittent P 1
# Median Extrospective State Rotate Fitness Differential @ Intermittent P 1
# Num More Fit Under Extrospective State Rotates
# Num Less Fit Under Extrospective State Rotates
# Fraction Extrospective State Rotates that are Advantageous
# Fraction Extrospective State Rotates that are Deleterious
# Mean Extrospective State Rotate Fitness Differential
# Median Extrospective State Rotate Fitness Differential
# Num More Fit Under Extrospective State Exchanges @ Intermittent P 1
# Num Less Fit Under Extrospective State Exchanges @ Intermittent P 1
# Fraction Extrospective State Exchanges that are Advantageous @ Intermittent P 1
# Fraction Extrospective State Exchanges that are Deleterious @ Intermittent P 1
# Mean Extrospective State Exchange Fitness Differential @ Intermittent P 1
# Median Extrospective State Exchange Fitness Differential @ Intermittent P 1
# Num More Fit Under Extrospective State Exchanges
# Num Less Fit Under Extrospective State Exchanges
# Fraction Extrospective State Exchanges that are Advantageous
# Fraction Extrospective State Exchanges that are Deleterious
# Mean Extrospective State Exchange Fitness Differential
# Median Extrospective State Exchange Fitness Differential
# Num More Fit Under Introspective State Rotates @ Intermittent P 1
# Num Less Fit Under Introspective State Rotates @ Intermittent P 1
# Fraction Introspective State Rotates that are Advantageous @ Intermittent P 1
# Fraction Introspective State Rotates that are Deleterious @ Intermittent P 1
# Mean Introspective State Rotate Fitness Differential @ Intermittent P 1
# Median Introspective State Rotate Fitness Differential @ Intermittent P 1
# Num More Fit Under Introspective State Rotates
# Num Less Fit Under Introspective State Rotates
# Fraction Introspective State Rotates that are Advantageous
# Fraction Introspective State Rotates that are Deleterious
# Mean Introspective State Rotate Fitness Differential
# Median Introspective State Rotate Fitness Differential
# Num More Fit Under Introspective State Exchanges @ Intermittent P 1
# Num Less Fit Under Introspective State Exchanges @ Intermittent P 1
# Fraction Introspective State Exchanges that are Advantageous @ Intermittent P 1
# Fraction Introspective State Exchanges that are Deleterious @ Intermittent P 1
# Mean Introspective State Exchange Fitness Differential @ Intermittent P 1
# Median Introspective State Exchange Fitness Differential @ Intermittent P 1
# Num More Fit Under Introspective State Exchanges
# Num Less Fit Under Introspective State Exchanges
# Fraction Introspective State Exchanges that are Advantageous
# Fraction Introspective State Exchanges that are Deleterious
# Mean Introspective State Exchange Fitness Differential
# Median Introspective State Exchange Fitness Differential
# Num More Fit Under Writable State Rotates @ Intermittent P 1
# Num Less Fit Under Writable State Rotates @ Intermittent P 1
# Fraction Writable State Rotates that are Advantageous @ Intermittent P 1
# Fraction Writable State Rotates that are Deleterious @ Intermittent P 1
# Mean Writable State Rotate Fitness Differential @ Intermittent P 1
# Median Writable State Rotate Fitness Differential @ Intermittent P 1
# Num More Fit Under Writable State Rotates
# Num Less Fit Under Writable State Rotates
# Fraction Writable State Rotates that are Advantageous
# Fraction Writable State Rotates that are Deleterious
# Mean Writable State Rotate Fitness Differential
# Median Writable State Rotate Fitness Differential
# Num More Fit Under Writable State Exchanges @ Intermittent P 1
# Num Less Fit Under Writable State Exchanges @ Intermittent P 1
# Fraction Writable State Exchanges that are Advantageous @ Intermittent P 1
# Fraction Writable State Exchanges that are Deleterious @ Intermittent P 1
# Mean Writable State Exchange Fitness Differential @ Intermittent P 1
# Median Writable State Exchange Fitness Differential @ Intermittent P 1
# Num More Fit Under Writable State Exchanges
# Num Less Fit Under Writable State Exchanges
# Fraction Writable State Exchanges that are Advantageous
# Fraction Writable State Exchanges that are Deleterious
# Mean Writable State Exchange Fitness Differential
# Median Writable State Exchange Fitness Differential
# Num More Fit Under Extrospective State Perturbation @ Intermittent P 1
# Num Less Fit Under Extrospective State Perturbation @ Intermittent P 1
# Fraction Extrospective State Perturbations that are Advantageous @ Intermittent P 1
# Fraction Extrospective State Perturbations that are Deleterious @ Intermittent P 1
# Mean Extrospective State Perturbation Fitness Differential @ Intermittent P 1
# Median Extrospective State Perturbation Fitness Differential @ Intermittent P 1
# Num More Fit Under Extrospective State Perturbation
# Num Less Fit Under Extrospective State Perturbation
# Fraction Extrospective State Perturbations that are Advantageous
# Fraction Extrospective State Perturbations that are Deleterious
# Mean Extrospective State Perturbation Fitness Differential
# Median Extrospective State Perturbation Fitness Differential
# Num More Fit Under Introspective State Perturbation @ Intermittent P 1
# Num Less Fit Under Introspective State Perturbation @ Intermittent P 1
# Fraction Introspective State Perturbations that are Advantageous @ Intermittent P 1
# Fraction Introspective State Perturbations that are Deleterious @ Intermittent P 1
# Mean Introspective State Perturbation Fitness Differential @ Intermittent P 1
# Median Introspective State Perturbation Fitness Differential @ Intermittent P 1
# Num More Fit Under Introspective State Perturbation
# Num Less Fit Under Introspective State Perturbation
# Fraction Introspective State Perturbations that are Advantageous
# Fraction Introspective State Perturbations that are Deleterious
# Mean Introspective State Perturbation Fitness Differential
# Median Introspective State Perturbation Fitness Differential
# Num More Fit Under Writable State Perturbation @ Intermittent P 1
# Num Less Fit Under Writable State Perturbation @ Intermittent P 1
# Fraction Writable State Perturbations that are Advantageous @ Intermittent P 1
# Fraction Writable State Perturbations that are Deleterious @ Intermittent P 1
# Mean Writable State Perturbation Fitness Differential @ Intermittent P 1
# Median Writable State Perturbation Fitness Differential @ Intermittent P 1
# Num More Fit Under Writable State Perturbation
# Num Less Fit Under Writable State Perturbation
# Fraction Writable State Perturbations that are Advantageous
# Fraction Writable State Perturbations that are Deleterious
# Mean Writable State Perturbation Fitness Differential
# Median Writable State Perturbation Fitness Differential
# Num More Fit Under Inter Self-Send @ Filter Mod 20
# Num Less Fit Under Inter Self-Send @ Filter Mod 20
# Fraction Inter Self-Sends that are Advantageous @ Filter Mod 20
# Fraction Inter Self-Sends that are Deleterious @ Filter Mod 20
# Mean Inter Self-Send Fitness Differential @ Filter Mod 20
# Median Inter Self-Send Fitness Differential @ Filter Mod 20
# Num More Fit Under Inter Self-Send
# Num Less Fit Under Inter Self-Send
# Fraction Inter Self-Sends that are Advantageous
# Fraction Inter Self-Sends that are Deleterious
# Mean Inter Self-Send Fitness Differential
# Median Inter Self-Send Fitness Differential
# Num More Fit Under Intra Self-Send @ Filter Mod 20
# Num Less Fit Under Intra Self-Send @ Filter Mod 20
# Fraction Intra Self-Sends that are Advantageous @ Filter Mod 20
# Fraction Intra Self-Sends that are Deleterious @ Filter Mod 20
# Mean Intra Self-Send Fitness Differential @ Filter Mod 20
# Median Intra Self-Send Fitness Differential @ Filter Mod 20
# Num More Fit Under Intra Self-Send
# Num Less Fit Under Intra Self-Send
# Fraction Intra Self-Sends that are Advantageous
# Fraction Intra Self-Sends that are Deleterious
# Mean Intra Self-Send Fitness Differential
# Median Intra Self-Send Fitness Differential
# Num More Fit Mutants
# Num Less Fit Mutants
# Fraction Mutations that are Advantageous
# Fraction Mutations that are Deleterious
# Mean Mutant Fitness Differential
# Median Mutant Fitness Differential
# none_nopped_is_less_fit
# all_nopped_is_less_fit
# credible_interval_lower_bound_idx
# most_credible_idx
# most_credible_likelihood
# most_credible_set_size
# interpolation_complexity
# credible_interval_upper_bound_idx
# a=credible_interval_lower_bound_idx+set_size=1
# a=most_credible_idx+set_size=1
# a=most_credible_likelihood+set_size=1
# a=credible_interval_upper_bound_idx+set_size=1
# a=credible_interval_lower_bound_idx+set_size=2
# a=most_credible_idx+set_size=2
# a=most_credible_likelihood+set_size=2
# a=credible_interval_upper_bound_idx+set_size=2
# a=credible_interval_lower_bound_idx+set_size=3
# a=most_credible_idx+set_size=3
# a=most_credible_likelihood+set_size=3
# a=credible_interval_upper_bound_idx+set_size=3
# Num More Fit Mutating Mutants
# Num Less Fit Mutating Mutants
# Fraction Mutating Mutations that are Advantageous
# Fraction Mutating Mutations that are Deleterious
# Mean Mutating Mutant Fitness Differential
# Median Mutating Mutant Fitness Differential
# Mean Doubling Time Growth Rate
# Test Stint
# Test Series
# Test Replicate
# Test Treatment
# Treatment _
# Treatment mut_sever
# Treatment mut_freq
# Treatment diversity
# Treatment bucket
# Test Endeavor
# Test Repro
# Competition Slurm Job ID
# Test Thread
# Test Process
# Update
# First Root ID
# Second Root ID
# First Genome Slug
# Second Genome Slug
# First Genome Filename
# Second Genome Filename
# Phenotype Divergence Detected
# first genome a
# first genome criteria
# first genome ext
# first genome morph
# first genome proc
# first genome root_id
# first genome series
# first genome stint
# first genome thread
# first genome variation
# second genome a
# second genome criteria
# second genome ext
# second genome morph
# second genome proc
# second genome root_id
# second genome series
# second genome stint
# second genome thread
# second genome variation
# Phenotype Neutral Nopout is Phenotypically Divergent
# Phenotype Neutral Nopout is Phenotypically Identical
# Fraction Phenotypically-Expressed Mutations
# Fraction Phenotypically-Neutral Mutations
# Mean Fitness Differential Against Predecessor Population
# Median Fitness Differential Against Predecessor Population
# Fraction Predecessor Battles Won
# Predecessor Battle Null p-value
# index
# Treatment
# 0
# Genome Slug
# Genome Filename
# Num Anchor Instructions
# Num Global Anchor Instructions
# Num Local Anchor Instructions
# Num Bitwise Instructions
# Num Intermessaging Instructions
# Num Intrinsic Instructions
# Num Extrinsic Instructions
# Num Flow Instructions
# Num Global Flow Instructions
# Num Local Flow Instructions
# Num Nop Instructions
# Num Op Instructions
# Num Actuator Instructions
# Num Calculation Instructions
# Num Regulation Instructions
# Num Global Regulation Instructions
# Num Local Regulation Instructions
# Program Compression Ratio
# Num Instructions
# Num Modules
# Coding Fraction
# Non-coding Fraction
# Elapsed Generations Level 0
# Elapsed Generations Level 1
# Elapsed Generations Level 2
# Elapsed Indel Mutations
# Elapsed Point Mutations
# Elapsed Mutations
# genome _
# genome _endeavor
# genome _repro
# genome _slurm_job_id
# genome _source
# genome _treatment
# genome a
# genome abundance
# genome count
# genome criteria
# genome ext
# genome morph
# genome prevalence
# genome proc
# genome series
# genome stint
# genome thread
# genome variation
# Phenotype Complexity
# Parent-Eliminated Kin ID Commonality=1+a=Treatment (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Treatment (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Treatment _ (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Treatment _ (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Treatment mut_sever (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Treatment mut_sever (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Treatment mut_freq (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Treatment mut_freq (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Treatment diversity (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Treatment diversity (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Treatment bucket (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Treatment bucket (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=proc (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=proc (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=thread (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=thread (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Num Spawn Events (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Num Spawn Events (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Spawn Event Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Spawn Event Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Total Num Kin Eliminated (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Total Num Kin Eliminated (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Fraction Eliminated that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Fraction Eliminated that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Fraction Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Fraction Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Fraction Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Fraction Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Kin Conflict Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Kin Conflict Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=1+a=Kin Conflict at Spawn Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=2+a=Kin Conflict at Spawn Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment _ (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment _ (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment _ (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment _ (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment _ (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment _ (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment mut_sever (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment mut_sever (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment mut_sever (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment mut_sever (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment mut_sever (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment mut_sever (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment mut_freq (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment mut_freq (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment mut_freq (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment mut_freq (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment mut_freq (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment mut_freq (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment diversity (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment diversity (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment diversity (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment diversity (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment diversity (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment diversity (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Treatment bucket (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Treatment bucket (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Treatment bucket (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Treatment bucket (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Treatment bucket (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Treatment bucket (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=proc (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=proc (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=proc (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=proc (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=proc (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=proc (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=thread (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=thread (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=thread (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=thread (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=thread (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=thread (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Num Spawn Events (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Num Spawn Events (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Num Spawn Events (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Num Spawn Events (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Num Spawn Events (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Num Spawn Events (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Total Num Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Total Num Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Total Num Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Total Num Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Total Num Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Total Num Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Total Num Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Total Num Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Total Num Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Total Num Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Total Num Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Total Num Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Total Num Spawn Event Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Total Num Spawn Event Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Total Num Spawn Event Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Total Num Spawn Event Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Total Num Spawn Event Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Total Num Spawn Event Neighbors (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Total Num Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Total Num Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Total Num Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Total Num Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Total Num Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Total Num Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Total Num Kin Eliminated (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Total Num Kin Eliminated (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Total Num Kin Eliminated (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Total Num Kin Eliminated (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Total Num Kin Eliminated (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Total Num Kin Eliminated (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Fraction Eliminated that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Fraction Eliminated that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Fraction Eliminated that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Fraction Eliminated that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Fraction Eliminated that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Fraction Eliminated that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Fraction Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Fraction Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Fraction Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Fraction Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Fraction Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Fraction Spawn Event Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Fraction Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Fraction Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Fraction Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Fraction Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Fraction Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Fraction Neighbors that are Kin (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Kin Conflict Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Kin Conflict Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Kin Conflict Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Kin Conflict Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Kin Conflict Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Kin Conflict Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=0+a=Kin Conflict at Spawn Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=1+a=Kin Conflict at Spawn Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=1+Replev=2+a=Kin Conflict at Spawn Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=0+a=Kin Conflict at Spawn Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=1+a=Kin Conflict at Spawn Ratio (monoculture)
# Parent-Eliminated Kin ID Commonality=2+Replev=2+a=Kin Conflict at Spawn Ratio (monoculture)
# proc (monoculture first)
# thread (monoculture first)
# Update (monoculture first)
# Cardinal Apoptosis Request Fraction (monoculture first)
# Cell Apoptosis Request Fraction (monoculture first)
# Extinct (monoculture first)
# Fecund Resource Stockpile Fraction (monoculture first)
# Fraction Deaths age (monoculture first)
# Fraction Deaths apoptosis (monoculture first)
# Fraction Deaths elimination (monoculture first)
# Fraction Deaths fragmentation (monoculture first)
# Fraction Deaths quorum (monoculture first)
# Fraction Deaths unknown (monoculture first)
# Fraction Kin Group Loner Cells Level 0 (monoculture first)
# Fraction Kin Group Loner Cells Level 1 (monoculture first)
# Fraction Live Cells (monoculture first)
# Fraction Neighbors Kin Level 0 (monoculture first)
# Fraction Neighbors Kin Level 1 (monoculture first)
# Incoming Inter Message Cardinal Fraction (monoculture first)
# Incoming Inter Message Cell Fraction (monoculture first)
# Incoming Intra Message Cardinal Fraction (monoculture first)
# Incoming Intra Message Cell Fraction (monoculture first)
# Maximum Kin Group Size Level 0 (monoculture first)
# Maximum Kin Group Size Level 1 (monoculture first)
# Mean Cell Age (monoculture first)
# Mean Current Epoch (monoculture first)
# Mean Elapsed Generations Level 0 (monoculture first)
# Mean Elapsed Generations Level 1 (monoculture first)
# Mean Elapsed Generations Level 2 (monoculture first)
# Mean Elapsed Indel Mutations (monoculture first)
# Mean Elapsed Mutation Occurences (monoculture first)
# Mean Elapsed Point Mutations (monoculture first)
# Mean Incoming Inter Message Count Per Cardinal (monoculture first)
# Mean Incoming Inter Message Count Per Cell (monoculture first)
# Mean Incoming Intra Message Count Per Cardinal (monoculture first)
# Mean Incoming Intra Message Count Per Cell (monoculture first)
# Mean Instructions Executed per Cardinal-update (monoculture first)
# Mean Kin Group Age Level 0 (monoculture first)
# Mean Kin Group Age Level 1 (monoculture first)
# Mean Kin Group Size Level 0 (monoculture first)
# Mean Kin Group Size Level 1 (monoculture first)
# Mean Program Instruction Count (monoculture first)
# Mean Program Module Count (monoculture first)
# Mean Resource Received Per Cardinal (monoculture first)
# Mean Resource Received Per Cell (monoculture first)
# Mean Resource Stockpile (monoculture first)
# Mean Spawn Count (monoculture first)
# Median Kin Group Size Level 0 (monoculture first)
# Median Kin Group Size Level 1 (monoculture first)
# Nulliparous Fraction (monoculture first)
# Num Births per Cell-update (monoculture first)
# Num Births per Live Cell-update  (monoculture first)
# Num Deaths age (monoculture first)
# Num Deaths apoptosis (monoculture first)
# Num Deaths elimination (monoculture first)
# Num Deaths fragmentation (monoculture first)
# Num Deaths per Cell-update (monoculture first)
# Num Deaths per Cell-update age (monoculture first)
# Num Deaths per Cell-update apoptosis (monoculture first)
# Num Deaths per Cell-update elimination (monoculture first)
# Num Deaths per Cell-update fragmentation (monoculture first)
# Num Deaths per Cell-update quorum (monoculture first)
# Num Deaths per Cell-update unknown (monoculture first)
# Num Deaths per Live Cell-update  (monoculture first)
# Num Deaths per Live Cell-update age (monoculture first)
# Num Deaths per Live Cell-update apoptosis (monoculture first)
# Num Deaths per Live Cell-update elimination (monoculture first)
# Num Deaths per Live Cell-update fragmentation (monoculture first)
# Num Deaths per Live Cell-update quorum (monoculture first)
# Num Deaths per Live Cell-update unknown (monoculture first)
# Num Deaths quorum (monoculture first)
# Num Deaths unknown (monoculture first)
# Num Instructions Executed per Live Cardinal-update (monoculture first)
# Num Spawn Events per Cell-update (monoculture first)
# Num Spawn Events per Live Cell-update  (monoculture first)
# Number Cardinals (monoculture first)
# Number Cells (monoculture first)
# Number Dead Cells (monoculture first)
# Number Live Cardinals (monoculture first)
# Number Live Cells (monoculture first)
# Number Phylogenetic Roots (monoculture first)
# Number Stint Phylogenetic Roots (monoculture first)
# Number Unique Genotypes (monoculture first)
# Number Unique Module Expression Profiles (monoculture first)
# Number Unique Module Regulation Profiles (monoculture first)
# Prevalent Genotype Quantity (monoculture first)
# Random Number Generator Seed (monoculture first)
# Resource Receive Resistance Cardinal Fraction (monoculture first)
# Resource Receive Resistance Cell Fraction (monoculture first)
# Resource Receiving Cardinal Fraction (monoculture first)
# Resource Receiving Cell Fraction (monoculture first)
# Resource Reserve Request Cardinal Fraction (monoculture first)
# Resource Reserve Request Cell Fraction (monoculture first)
# Resource Send Request Cardinal Fraction (monoculture first)
# Resource Send Request Cell Fraction (monoculture first)
# Spawn Arrest Cardinal Fraction (monoculture first)
# Spawn Arrest Cell Fraction (monoculture first)
# Spawn Request Cardinal Fraction (monoculture first)
# Spawn Request Cell Fraction (monoculture first)
# proc (evolve first)
# thread (evolve first)
# Update (evolve first)
# Cardinal Apoptosis Request Fraction (evolve first)
# Cell Apoptosis Request Fraction (evolve first)
# Extinct (evolve first)
# Fecund Resource Stockpile Fraction (evolve first)
# Fraction Deaths age (evolve first)
# Fraction Deaths apoptosis (evolve first)
# Fraction Deaths elimination (evolve first)
# Fraction Deaths fragmentation (evolve first)
# Fraction Deaths quorum (evolve first)
# Fraction Deaths unknown (evolve first)
# Fraction Kin Group Loner Cells Level 0 (evolve first)
# Fraction Kin Group Loner Cells Level 1 (evolve first)
# Fraction Live Cells (evolve first)
# Fraction Neighbors Kin Level 0 (evolve first)
# Fraction Neighbors Kin Level 1 (evolve first)
# Incoming Inter Message Cardinal Fraction (evolve first)
# Incoming Inter Message Cell Fraction (evolve first)
# Incoming Intra Message Cardinal Fraction (evolve first)
# Incoming Intra Message Cell Fraction (evolve first)
# Maximum Kin Group Size Level 0 (evolve first)
# Maximum Kin Group Size Level 1 (evolve first)
# Mean Cell Age (evolve first)
# Mean Current Epoch (evolve first)
# Mean Elapsed Generations Level 0 (evolve first)
# Mean Elapsed Generations Level 1 (evolve first)
# Mean Elapsed Generations Level 2 (evolve first)
# Mean Elapsed Indel Mutations (evolve first)
# Mean Elapsed Mutation Occurences (evolve first)
# Mean Elapsed Point Mutations (evolve first)
# Mean Incoming Inter Message Count Per Cardinal (evolve first)
# Mean Incoming Inter Message Count Per Cell (evolve first)
# Mean Incoming Intra Message Count Per Cardinal (evolve first)
# Mean Incoming Intra Message Count Per Cell (evolve first)
# Mean Instructions Executed per Cardinal-update (evolve first)
# Mean Kin Group Age Level 0 (evolve first)
# Mean Kin Group Age Level 1 (evolve first)
# Mean Kin Group Size Level 0 (evolve first)
# Mean Kin Group Size Level 1 (evolve first)
# Mean Program Instruction Count (evolve first)
# Mean Program Module Count (evolve first)
# Mean Resource Received Per Cardinal (evolve first)
# Mean Resource Received Per Cell (evolve first)
# Mean Resource Stockpile (evolve first)
# Mean Spawn Count (evolve first)
# Median Kin Group Size Level 0 (evolve first)
# Median Kin Group Size Level 1 (evolve first)
# Nulliparous Fraction (evolve first)
# Num Births per Cell-update (evolve first)
# Num Births per Live Cell-update  (evolve first)
# Num Deaths age (evolve first)
# Num Deaths apoptosis (evolve first)
# Num Deaths elimination (evolve first)
# Num Deaths fragmentation (evolve first)
# Num Deaths per Cell-update (evolve first)
# Num Deaths per Cell-update age (evolve first)
# Num Deaths per Cell-update apoptosis (evolve first)
# Num Deaths per Cell-update elimination (evolve first)
# Num Deaths per Cell-update fragmentation (evolve first)
# Num Deaths per Cell-update quorum (evolve first)
# Num Deaths per Cell-update unknown (evolve first)
# Num Deaths per Live Cell-update  (evolve first)
# Num Deaths per Live Cell-update age (evolve first)
# Num Deaths per Live Cell-update apoptosis (evolve first)
# Num Deaths per Live Cell-update elimination (evolve first)
# Num Deaths per Live Cell-update fragmentation (evolve first)
# Num Deaths per Live Cell-update quorum (evolve first)
# Num Deaths per Live Cell-update unknown (evolve first)
# Num Deaths quorum (evolve first)
# Num Deaths unknown (evolve first)
# Num Instructions Executed per Live Cardinal-update (evolve first)
# Num Spawn Events per Cell-update (evolve first)
# Num Spawn Events per Live Cell-update  (evolve first)
# Number Cardinals (evolve first)
# Number Cells (evolve first)
# Number Dead Cells (evolve first)
# Number Live Cardinals (evolve first)
# Number Live Cells (evolve first)
# Number Phylogenetic Roots (evolve first)
# Number Stint Phylogenetic Roots (evolve first)
# Number Unique Genotypes (evolve first)
# Number Unique Module Expression Profiles (evolve first)
# Number Unique Module Regulation Profiles (evolve first)
# Prevalent Genotype Quantity (evolve first)
# Random Number Generator Seed (evolve first)
# Resource Receive Resistance Cardinal Fraction (evolve first)
# Resource Receive Resistance Cell Fraction (evolve first)
# Resource Receiving Cardinal Fraction (evolve first)
# Resource Receiving Cell Fraction (evolve first)
# Resource Reserve Request Cardinal Fraction (evolve first)
# Resource Reserve Request Cell Fraction (evolve first)
# Resource Send Request Cardinal Fraction (evolve first)
# Resource Send Request Cell Fraction (evolve first)
# Spawn Arrest Cardinal Fraction (evolve first)
# Spawn Arrest Cell Fraction (evolve first)
# Spawn Request Cardinal Fraction (evolve first)
# Spawn Request Cell Fraction (evolve first)
# proc (monoculture mean)
# thread (monoculture mean)
# Update (monoculture mean)
# Cardinal Apoptosis Request Fraction (monoculture mean)
# Cell Apoptosis Request Fraction (monoculture mean)
# Extinct (monoculture mean)
# Fecund Resource Stockpile Fraction (monoculture mean)
# Fraction Deaths age (monoculture mean)
# Fraction Deaths apoptosis (monoculture mean)
# Fraction Deaths elimination (monoculture mean)
# Fraction Deaths fragmentation (monoculture mean)
# Fraction Deaths quorum (monoculture mean)
# Fraction Deaths unknown (monoculture mean)
# Fraction Kin Group Loner Cells Level 0 (monoculture mean)
# Fraction Kin Group Loner Cells Level 1 (monoculture mean)
# Fraction Live Cells (monoculture mean)
# Fraction Neighbors Kin Level 0 (monoculture mean)
# Fraction Neighbors Kin Level 1 (monoculture mean)
# Incoming Inter Message Cardinal Fraction (monoculture mean)
# Incoming Inter Message Cell Fraction (monoculture mean)
# Incoming Intra Message Cardinal Fraction (monoculture mean)
# Incoming Intra Message Cell Fraction (monoculture mean)
# Maximum Kin Group Size Level 0 (monoculture mean)
# Maximum Kin Group Size Level 1 (monoculture mean)
# Mean Cell Age (monoculture mean)
# Mean Current Epoch (monoculture mean)
# Mean Elapsed Generations Level 0 (monoculture mean)
# Mean Elapsed Generations Level 1 (monoculture mean)
# Mean Elapsed Generations Level 2 (monoculture mean)
# Mean Elapsed Indel Mutations (monoculture mean)
# Mean Elapsed Mutation Occurences (monoculture mean)
# Mean Elapsed Point Mutations (monoculture mean)
# Mean Incoming Inter Message Count Per Cardinal (monoculture mean)
# Mean Incoming Inter Message Count Per Cell (monoculture mean)
# Mean Incoming Intra Message Count Per Cardinal (monoculture mean)
# Mean Incoming Intra Message Count Per Cell (monoculture mean)
# Mean Instructions Executed per Cardinal-update (monoculture mean)
# Mean Kin Group Age Level 0 (monoculture mean)
# Mean Kin Group Age Level 1 (monoculture mean)
# Mean Kin Group Size Level 0 (monoculture mean)
# Mean Kin Group Size Level 1 (monoculture mean)
# Mean Program Instruction Count (monoculture mean)
# Mean Program Module Count (monoculture mean)
# Mean Resource Received Per Cardinal (monoculture mean)
# Mean Resource Received Per Cell (monoculture mean)
# Mean Resource Stockpile (monoculture mean)
# Mean Spawn Count (monoculture mean)
# Median Kin Group Size Level 0 (monoculture mean)
# Median Kin Group Size Level 1 (monoculture mean)
# Nulliparous Fraction (monoculture mean)
# Num Births per Cell-update (monoculture mean)
# Num Births per Live Cell-update  (monoculture mean)
# Num Deaths age (monoculture mean)
# Num Deaths apoptosis (monoculture mean)
# Num Deaths elimination (monoculture mean)
# Num Deaths fragmentation (monoculture mean)
# Num Deaths per Cell-update (monoculture mean)
# Num Deaths per Cell-update age (monoculture mean)
# Num Deaths per Cell-update apoptosis (monoculture mean)
# Num Deaths per Cell-update elimination (monoculture mean)
# Num Deaths per Cell-update fragmentation (monoculture mean)
# Num Deaths per Cell-update quorum (monoculture mean)
# Num Deaths per Cell-update unknown (monoculture mean)
# Num Deaths per Live Cell-update  (monoculture mean)
# Num Deaths per Live Cell-update age (monoculture mean)
# Num Deaths per Live Cell-update apoptosis (monoculture mean)
# Num Deaths per Live Cell-update elimination (monoculture mean)
# Num Deaths per Live Cell-update fragmentation (monoculture mean)
# Num Deaths per Live Cell-update quorum (monoculture mean)
# Num Deaths per Live Cell-update unknown (monoculture mean)
# Num Deaths quorum (monoculture mean)
# Num Deaths unknown (monoculture mean)
# Num Instructions Executed per Live Cardinal-update (monoculture mean)
# Num Spawn Events per Cell-update (monoculture mean)
# Num Spawn Events per Live Cell-update  (monoculture mean)
# Number Cardinals (monoculture mean)
# Number Cells (monoculture mean)
# Number Dead Cells (monoculture mean)
# Number Live Cardinals (monoculture mean)
# Number Live Cells (monoculture mean)
# Number Phylogenetic Roots (monoculture mean)
# Number Stint Phylogenetic Roots (monoculture mean)
# Number Unique Genotypes (monoculture mean)
# Number Unique Module Expression Profiles (monoculture mean)
# Number Unique Module Regulation Profiles (monoculture mean)
# Prevalent Genotype Quantity (monoculture mean)
# Random Number Generator Seed (monoculture mean)
# Resource Receive Resistance Cardinal Fraction (monoculture mean)
# Resource Receive Resistance Cell Fraction (monoculture mean)
# Resource Receiving Cardinal Fraction (monoculture mean)
# Resource Receiving Cell Fraction (monoculture mean)
# Resource Reserve Request Cardinal Fraction (monoculture mean)
# Resource Reserve Request Cell Fraction (monoculture mean)
# Resource Send Request Cardinal Fraction (monoculture mean)
# Resource Send Request Cell Fraction (monoculture mean)
# Spawn Arrest Cardinal Fraction (monoculture mean)
# Spawn Arrest Cell Fraction (monoculture mean)
# Spawn Request Cardinal Fraction (monoculture mean)
# Spawn Request Cell Fraction (monoculture mean)
# proc (evolve mean)
# thread (evolve mean)
# Update (evolve mean)
# Cardinal Apoptosis Request Fraction (evolve mean)
# Cell Apoptosis Request Fraction (evolve mean)
# Extinct (evolve mean)
# Fecund Resource Stockpile Fraction (evolve mean)
# Fraction Deaths age (evolve mean)
# Fraction Deaths apoptosis (evolve mean)
# Fraction Deaths elimination (evolve mean)
# Fraction Deaths fragmentation (evolve mean)
# Fraction Deaths quorum (evolve mean)
# Fraction Deaths unknown (evolve mean)
# Fraction Kin Group Loner Cells Level 0 (evolve mean)
# Fraction Kin Group Loner Cells Level 1 (evolve mean)
# Fraction Live Cells (evolve mean)
# Fraction Neighbors Kin Level 0 (evolve mean)
# Fraction Neighbors Kin Level 1 (evolve mean)
# Incoming Inter Message Cardinal Fraction (evolve mean)
# Incoming Inter Message Cell Fraction (evolve mean)
# Incoming Intra Message Cardinal Fraction (evolve mean)
# Incoming Intra Message Cell Fraction (evolve mean)
# Maximum Kin Group Size Level 0 (evolve mean)
# Maximum Kin Group Size Level 1 (evolve mean)
# Mean Cell Age (evolve mean)
# Mean Current Epoch (evolve mean)
# Mean Elapsed Generations Level 0 (evolve mean)
# Mean Elapsed Generations Level 1 (evolve mean)
# Mean Elapsed Generations Level 2 (evolve mean)
# Mean Elapsed Indel Mutations (evolve mean)
# Mean Elapsed Mutation Occurences (evolve mean)
# Mean Elapsed Point Mutations (evolve mean)
# Mean Incoming Inter Message Count Per Cardinal (evolve mean)
# Mean Incoming Inter Message Count Per Cell (evolve mean)
# Mean Incoming Intra Message Count Per Cardinal (evolve mean)
# Mean Incoming Intra Message Count Per Cell (evolve mean)
# Mean Instructions Executed per Cardinal-update (evolve mean)
# Mean Kin Group Age Level 0 (evolve mean)
# Mean Kin Group Age Level 1 (evolve mean)
# Mean Kin Group Size Level 0 (evolve mean)
# Mean Kin Group Size Level 1 (evolve mean)
# Mean Program Instruction Count (evolve mean)
# Mean Program Module Count (evolve mean)
# Mean Resource Received Per Cardinal (evolve mean)
# Mean Resource Received Per Cell (evolve mean)
# Mean Resource Stockpile (evolve mean)
# Mean Spawn Count (evolve mean)
# Median Kin Group Size Level 0 (evolve mean)
# Median Kin Group Size Level 1 (evolve mean)
# Nulliparous Fraction (evolve mean)
# Num Births per Cell-update (evolve mean)
# Num Births per Live Cell-update  (evolve mean)
# Num Deaths age (evolve mean)
# Num Deaths apoptosis (evolve mean)
# Num Deaths elimination (evolve mean)
# Num Deaths fragmentation (evolve mean)
# Num Deaths per Cell-update (evolve mean)
# Num Deaths per Cell-update age (evolve mean)
# Num Deaths per Cell-update apoptosis (evolve mean)
# Num Deaths per Cell-update elimination (evolve mean)
# Num Deaths per Cell-update fragmentation (evolve mean)
# Num Deaths per Cell-update quorum (evolve mean)
# Num Deaths per Cell-update unknown (evolve mean)
# Num Deaths per Live Cell-update  (evolve mean)
# Num Deaths per Live Cell-update age (evolve mean)
# Num Deaths per Live Cell-update apoptosis (evolve mean)
# Num Deaths per Live Cell-update elimination (evolve mean)
# Num Deaths per Live Cell-update fragmentation (evolve mean)
# Num Deaths per Live Cell-update quorum (evolve mean)
# Num Deaths per Live Cell-update unknown (evolve mean)
# Num Deaths quorum (evolve mean)
# Num Deaths unknown (evolve mean)
# Num Instructions Executed per Live Cardinal-update (evolve mean)
# Num Spawn Events per Cell-update (evolve mean)
# Num Spawn Events per Live Cell-update  (evolve mean)
# Number Cardinals (evolve mean)
# Number Cells (evolve mean)
# Number Dead Cells (evolve mean)
# Number Live Cardinals (evolve mean)
# Number Live Cells (evolve mean)
# Number Phylogenetic Roots (evolve mean)
# Number Stint Phylogenetic Roots (evolve mean)
# Number Unique Genotypes (evolve mean)
# Number Unique Module Expression Profiles (evolve mean)
# Number Unique Module Regulation Profiles (evolve mean)
# Prevalent Genotype Quantity (evolve mean)
# Random Number Generator Seed (evolve mean)
# Resource Receive Resistance Cardinal Fraction (evolve mean)
# Resource Receive Resistance Cell Fraction (evolve mean)
# Resource Receiving Cardinal Fraction (evolve mean)
# Resource Receiving Cell Fraction (evolve mean)
# Resource Reserve Request Cardinal Fraction (evolve mean)
# Resource Reserve Request Cell Fraction (evolve mean)
# Resource Send Request Cardinal Fraction (evolve mean)
# Resource Send Request Cell Fraction (evolve mean)
# Spawn Arrest Cardinal Fraction (evolve mean)
# Spawn Arrest Cell Fraction (evolve mean)
# Spawn Request Cardinal Fraction (evolve mean)
# Spawn Request Cell Fraction (evolve mean)
# Parent-Eliminated Kin ID Commonality=1+a=Treatment
# Parent-Eliminated Kin ID Commonality=2+a=Treatment
# Parent-Eliminated Kin ID Commonality=1+a=Treatment _
# Parent-Eliminated Kin ID Commonality=2+a=Treatment _
# Parent-Eliminated Kin ID Commonality=1+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=2+a=Treatment mut_sever
# Parent-Eliminated Kin ID Commonality=1+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=2+a=Treatment mut_freq
# Parent-Eliminated Kin ID Commonality=1+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=2+a=Treatment diversity
# Parent-Eliminated Kin ID Commonality=1+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=2+a=Treatment bucket
# Parent-Eliminated Kin ID Commonality=1+a=proc
# Parent-Eliminated Kin ID Commonality=2+a=proc
# Parent-Eliminated Kin ID Commonality=1+a=thread
# Parent-Eliminated Kin ID Commonality=2+a=thread
# Parent-Eliminated Kin ID Commonality=1+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=2+a=Num Spawn Events
# Parent-Eliminated Kin ID Commonality=1+a=Total Num
Perturbation @ Intermittent P 1
# Is More Fit Under Writable State 17 Perturbation @ Intermittent P 1
# Is Less Fit Under Writable State 17 Perturbation @ Intermittent P 1
# Is More Fit Under Writable State 0 Perturbation
# Is Less Fit Under Writable State 0 Perturbation
# Is More Fit Under Writable State 1 Perturbation
# Is Less Fit Under Writable State 1 Perturbation
# Is More Fit Under Writable State 2 Perturbation
# Is Less Fit Under Writable State 2 Perturbation
# Is More Fit Under Writable State 3 Perturbation
# Is Less Fit Under Writable State 3 Perturbation
# Is More Fit Under Writable State 4 Perturbation
# Is Less Fit Under Writable State 4 Perturbation
# Is More Fit Under Writable State 5 Perturbation
# Is Less Fit Under Writable State 5 Perturbation
# Is More Fit Under Writable State 6 Perturbation
# Is Less Fit Under Writable State 6 Perturbation
# Is More Fit Under Writable State 7 Perturbation
# Is Less Fit Under Writable State 7 Perturbation
# Is More Fit Under Writable State 8 Perturbation
# Is Less Fit Under Writable State 8 Perturbation
# Is More Fit Under Writable State 9 Perturbation
# Is Less Fit Under Writable State 9 Perturbation
# Is More Fit Under Writable State 10 Perturbation
# Is Less Fit Under Writable State 10 Perturbation
# Is More Fit Under Writable State 11 Perturbation
# Is Less Fit Under Writable State 11 Perturbation
# Is More Fit Under Writable State 12 Perturbation
# Is Less Fit Under Writable State 12 Perturbation
# Is More Fit Under Writable State 13 Perturbation
# Is Less Fit Under Writable State 13 Perturbation
# Is More Fit Under Writable State 14 Perturbation
# Is Less Fit Under Writable State 14 Perturbation
# Is More Fit Under Writable State 15 Perturbation
# Is Less Fit Under Writable State 15 Perturbation
# Is More Fit Under Writable State 16 Perturbation
# Is Less Fit Under Writable State 16 Perturbation
# Is More Fit Under Writable State 17 Perturbation
# Is Less Fit Under Writable State 17 Perturbation
# a=credible_interval_lower_bound_idx+set_size=4
# a=most_credible_idx+set_size=4
# a=most_credible_likelihood+set_size=4
# a=credible_interval_upper_bound_idx+set_size=4
# a=credible_interval_lower_bound_idx+set_size=5
# a=most_credible_idx+set_size=5
# a=most_credible_likelihood+set_size=5
# a=credible_interval_upper_bound_idx+set_size=5
# Bucket
# Fitness Complexity
# Number Unique Module Expression Profiles
# Number Unique Module Regulation Profiles
# Num Instructions Executed per Live Cardinal-update
# Mean Resource Received Per Cell
# Resource Receiving Cell Fraction
# Fraction Deaths apoptosis
# Fraction Deaths elimination
# Nulliparous Fraction
# Mean Kin Group Size Level 0
# Mean Kin Group Size Level 1
# Expected Mutations
# Mutation Accumulation
# Elapsed Generations
# Selection Pressure
# % Generations Level 0
# % Generations Level 1
# % Generations Level 2
# Mean Mutations per Generation
# Fitness Complexity Delta
# Fitness Complexity Delta %
# Fitness Complexity Delta Sign
# Phenotype Complexity Delta
# Phenotype Complexity Delta %
# Phenotype Complexity Delta Sign
# Predecessor Battle Outcome
# Neutral Phenotypic Variation Under Mutation
# Fraction Phenotypic Variation That Is Neutral Under Mutation
# Num Less Fit Under State Exchanges
# Num Less Fit Under State Rotates
# Num Less Fit Under State Perturbation
# Cardinal Interface Complexity
# Cell Interface Complexity
# Fraction Neighbors Exactly Kin Level 1 (monoculture mean)
# Parent-Eliminated Kin ID Commonality>=1+Statistic=Frequency+What=birth (monoculture)
# Birth Conflict Ratio for Kin Commonality At Least 1
# Birth Conflict Ratio for Kin Commonality Exactly 1
# Birth Conflict Ratio for Kin Commonality Exactly 2
# Stint Decade
# Critical Fitness Complexity
# Interpolated Fitness Complexity
# Composite Fitness Complexity
# More Fit than Predecessor
# Less Fit than Predecessor
# Predecessor Fitness Differentiation
# Predecessor Fitness Neutrality
# Morph
# proc
# thread
# Lowest Num Stint Root IDs
# Lowest Root ID

# %% [markdown]
# ## Fitness Data

# %%
background_key = {
    "immediatepredecessor-simuls-dosecorrected-withbioticbackground-withmut"
        : "Prefatory",
    "immediatepredecessor-simuls-dosecorrected-withfuturebioticbackground-withmut"
        : "Contemporary",
    "immediatepredecessor-simuls-nobioticbackground-withmut"
        : "Without",
    "lowestroot-immediatepredecessor-battles"
        : "Without",
    "immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withbioticbackground-withmut"
        : "Prefatory\n(no diversity maint.)",
    "immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withfuturebioticbackground-withmut"
        : "Contemporary\n(no diversity maint.)",
    "immediatepredecessor-battles-dosecorrected-withbioticbackground-withmut"
        : "Prefatory",
    "immediatepredecessor-battles-dosecorrected-withfuturebioticbackground-withmut"
        : "Contemporary",
}

# %%
color_key = {
    'a' : 'tab:blue',
    'b' : 'tab:orange',
    'c' : 'tab:green',
    'd' : 'tab:red',
    'e' : 'tab:purple',
    'f' : 'tab:brown',
    'g' : 'tab:pink',
    'h' : 'tab:gray',
    'i' : 'tab:olive',
    'j' : 'tab:cyan',
}

# %%
morph_key = {
    row['Stint'] : row['Morph']
    for idx, row in df_morph.iterrows()
}

# %%
def subject_key(setup: str) -> str:
    if 'simul' in setup or 'competition' in setup:
        return 'Specimen'
    elif 'battle' in setup:
        return 'Population'
    else:
        assert False

# %%
dfs_fit = []
for setup in (
    "immediatepredecessor-simuls-dosecorrected-withbioticbackground-withmut",
    "immediatepredecessor-simuls-dosecorrected-withfuturebioticbackground-withmut",
    "immediatepredecessor-simuls-nobioticbackground-withmut",
    "lowestroot-immediatepredecessor-battles",
    "immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withbioticbackground-withmut",
    "immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withfuturebioticbackground-withmut",
    "immediatepredecessor-battles-dosecorrected-withbioticbackground-withmut",
    "immediatepredecessor-battles-dosecorrected-withfuturebioticbackground-withmut",
):
    print(setup)
    df_fit = pd.read_csv(
        f"https://prq49.s3.us-east-2.amazonaws.com/endeavor%3D16/{setup}/stage%3D2%2Bwhat%3Dcollated/a%3Dconcat%2Bhow%3Dmanual%2Bext%3D.csv",
    )
    df_fit["setup"] = setup
    if "Fitness Differential Focal" not in df_fit:
        df_fit["Fitness Differential Focal"] = df_fit["Fitness Differential"]
    if "Focal Prevalence" not in df_fit:
        df_fit["Focal Prevalence"] = df_fit["Prevalence"]
    if "Focal Abundance" not in df_fit:
        df_fit["Focal Abundance"] = df_fit["Abundance"]

    df_fit['Positive Fitness Differential Focal'] = df_fit['Fitness Differential Focal'] > 0

    dfs_fit.append(df_fit)
# Out:
# immediatepredecessor-simuls-dosecorrected-withbioticbackground-withmut
# immediatepredecessor-simuls-dosecorrected-withfuturebioticbackground-withmut
# immediatepredecessor-simuls-nobioticbackground-withmut
# lowestroot-immediatepredecessor-battles
# immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withbioticbackground-withmut
# immediatepredecessor-simuls-dosecorrected-nodiversitymaintenance-withfuturebioticbackground-withmut
# immediatepredecessor-battles-dosecorrected-withbioticbackground-withmut
# immediatepredecessor-battles-dosecorrected-withfuturebioticbackground-withmut

# %%
df_fit = pd.concat(dfs_fit, ignore_index=True)
df_fit['Biotic Background'] = df_fit['setup'].apply(lambda setup: background_key[setup])
df_fit['Assay Subject'] = df_fit['setup'].apply(lambda setup: subject_key(setup))
df_fit['Assay Subject'] = df_fit['setup'].apply(lambda setup: subject_key(setup))

# %%
df_fit = df_fit[
    (df_fit["Root ID"] == 1)
    & (df_fit["Competition Stint"] > 0)
]

# %%
# adapted from https://stackoverflow.com/a/49601444
def lighten_color(color, amount=0.5):
    """
    Lightens the given color by multiplying (1-luminosity) by the given amount.
    Input can be matplotlib color string, hex string, or RGB tuple.

    Examples:
    >> lighten_color('g', 0.3)
    >> lighten_color('#F034A3', 0.6)
    >> lighten_color((.3,.55,.1), 0.5)
    """
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    r, g, b = mc.to_rgb(c)
    return r + amount * (1 - r), g + amount * (1 - g), b + amount * (1 - b)

# %%
df["Mutational Sensitivity"] = 1 - df["Fraction Mutations that are Deleterious"]

# %%
prev_stint = [  # from phylo
    0,  # 0
    1,  # 1
    2,  # 2
    2,  # 3
    3,  # 4
    3,  # 5
    3,  # 6
    6,  # 7
    6,  # 8
    5,  # 9
    9,  # 10
    10, # 11
    9,  # 12
    12,  # 13
    13,  # 14
    13,  # 15
    15,  # 16
    16,  # 17
    17,  # 18
    18,  # 19
    18,  # 20
    20,  # 21
    21,  # 22
    19,  # 23
    23,  # 24
    24,  # 25
    24,  # 26
    24,  # 27
    26,  # 28
    27,  # 29
    29,  # 30
    29,  # 31
    29,  # 32
    30,  # 33
    32,  # 34
    34,  # 35
    33,  # 36
    36,  # 37
    37,  # 38
    36,  # 39
    38,  # 40
    39,  # 41
    40,  # 42
    41,  # 43
    42,  # 44
    42,  # 45
    45,  # 46
    46,  # 47
    47,  # 48
    46,  # 49
    49,  # 50
    49,  # 51
    49,  # 52
    52,  # 53
    49,  # 54
    49,  # 55
    55,  # 56
    56,  # 57
    55,  # 58
    56,  # 59
    57,  # 60
    60,  # 61
    61,  # 62
    57,  # 63
    63,  # 64
    64,  # 65
    63,  # 66
    66,  # 67
    64,  # 68
    63,  # 69
    68,  # 70
    69,  # 71
    69,  # 72
    72,  # 73
    68,  # 74
    73,  # 75
    73,  # 76
    76,  # 77
    68,  # 78
    76,  # 79
    78,  # 80
    79,  # 81
    80,  # 82
    80,  # 83
    83,  # 84
    83,  # 85
    85,  # 86
    80,  # 87
    85,  # 88
    87,  # 89
    87,  # 90
    90,  # 91
    89,  # 92
    90,  # 93
    93,  # 94
    93,  # 95
    93,  # 96
    94,  # 97
    94,  # 98
    98,  # 99
    99, # 100
]
import numpy as np
prev_stint_np = np.array(prev_stint)

# %% [markdown]
# ## Plotting

# %%
data_df = df.sort_values(
    "Stint",
).loc[
    (
        (df["Series"] == 16005)
    ),
].sort_values("Stint")
data_df["prevcplx"] = data_df["Critical Fitness Complexity"].to_numpy()[
    prev_stint_np
]
data_df
# Out:
#                  Repro  Endeavor  Slurm Job ID  N_THREADS  RUN  RUN_UPDATES  \
# 5     XErLVfbqLT60JFeE        16      20670395          4    1            0
# 45    NvxfoVpRXCKuxye7        16      20672994          4    1            0
# 525   mzh5wPEvHyIYjQ3T        16      20681956          4    1            0
# 965   MeH88coMRwHapqYG        16      20691856          4    1            0
# 1405  Ni6qp1umTyXmhCLa        16      20705685          4    1            0
# ...                ...       ...           ...        ...  ...          ...
# 3885  0fGpqcwabVBHFesQ        16      22563551          4    1            0
# 3925  lsfTCcEePpfTBkZu        16      22569089          4    1            0
# 3965  2iWuQ4Xiga3AmLtL        16      22577898          4    1            0
# 4005  BB9KkPnSoj9qwQce        16      22586176          4    1            0
# 125   wrMyS2wFIvkGAkqy        16      22593414          4    1            0
#
#       RUN_SECONDS  MAIN_TIMEOUT_SECONDS  END_SNAPSHOT_TIMEOUT_SECONDS  \
# 5           10800                 13500                          1200
# 45          10800                 13500                          1200
# 525         10800                 13500                          1200
# 965         10800                 13500                          1200
# 1405        10800                 13500                          1200
# ...           ...                   ...                           ...
# 3885        10800                 13500                          1200
# 3925        10800                 13500                          1200
# 3965        10800                 13500                          1200
# 4005        10800                 13500                          1200
# 125         10800                 13500                          1200
#
#       LOG_FREQ  ...  Less Fit than Predecessor  \
# 5           20  ...                      False
# 45          20  ...                      False
# 525         20  ...                      False
# 965         20  ...                      False
# 1405        20  ...                      False
# ...        ...  ...                        ...
# 3885        20  ...                       True
# 3925        20  ...                      False
# 3965        20  ...                      False
# 4005        20  ...                      False
# 125         20  ...                      False
#
#       Predecessor Fitness Differentiation  Predecessor Fitness Neutrality  \
# 5                                   False                            True
# 45                                   True                           False
# 525                                  True                           False
# 965                                  True                           False
# 1405                                 True                           False
# ...                                   ...                             ...
# 3885                                False                            True
# 3925                                 True                           False
# 3965                                 True                           False
# 4005                                 True                           False
# 125                                  True                           False
#
#       Morph proc  thread  Lowest Num Stint Root IDs  Lowest Root ID  \
# 5         a  0.0     1.5                       1.00          2378.0
# 45        b  0.0     1.5                       1.25          2378.0
# 525       c  0.0     1.5                       2.25         12634.0
# 965       b  0.0     1.5                       5.75         12634.0
# 1405      b  0.0     1.5                       4.25         12634.0
# ...     ...  ...     ...                        ...             ...
# 3885      b  0.0     1.5                      14.50         12634.0
# 3925      h  0.0     1.5                      11.50         12634.0
# 3965      e  0.0     1.5                      17.75         12634.0
# 4005      e  0.0     1.5                      17.50         12634.0
# 125       j  0.0     1.5                      24.25         12634.0
#
#       Mutational Sensitivity  prevcplx
# 5                       0.80      5.84
# 45                      0.85      7.52
# 525                     0.80     16.57
# 965                     0.90     16.57
# 1405                    1.00      9.48
# ...                      ...       ...
# 3885                    0.70     31.42
# 3925                    0.45     31.90
# 3965                    0.50     31.90
# 4005                    0.65     26.92
# 125                     0.30     30.90
#
# [101 rows x 3059 columns]

# %%
data_fit = df_fit.sort_values(
    "Competition Stint",
).loc[
    (
        # (df_fit["Competition Stint"] > 1)
        (df_fit["Assay Subject"] == "Population")
        & (df_fit["Biotic Background"] == "Contemporary")
    ),
].groupby(
    "Competition Stint",
).median(numeric_only=True).reset_index()
data_fit
# Out:
#     Competition Stint  Competition Series  Competition Replicate  \
# 0                   1             16005.0                    9.5
# 1                   2             16005.0                    9.5
# 2                   3             16005.0                    9.5
# 3                   4             16005.0                    9.5
# 4                   5             16005.0                    9.5
# ..                ...                 ...                    ...
# 95                 96             16005.0                    9.5
# 96                 97             16005.0                    9.5
# 97                 98             16005.0                    9.5
# 98                 99             16005.0                    9.5
# 99                100             16005.0                    9.5
#
#     Treatment mut_sever  Treatment mut_freq  Competition Endeavor  \
# 0                   1.0                 1.0                  16.0
# 1                   1.0                 1.0                  16.0
# 2                   1.0                 1.0                  16.0
# 3                   1.0                 1.0                  16.0
# 4                   1.0                 1.0                  16.0
# ..                  ...                 ...                   ...
# 95                  1.0                 1.0                  16.0
# 96                  1.0                 1.0                  16.0
# 97                  1.0                 1.0                  16.0
# 98                  1.0                 1.0                  16.0
# 99                  1.0                 1.0                  16.0
#
#     Competition Slurm Job ID  Competition Thread  Competition Process  Update  \
# 0                 64337584.0                 0.0                  0.0  8735.5
# 1                 64215289.0                 0.0                  0.0  9124.5
# 2                 64337829.0                 0.0                  0.0  8123.0
# 3                 64337788.5                 0.0                  0.0  7822.0
# 4                 64215681.5                 0.0                  0.0  8405.0
# ..                       ...                 ...                  ...     ...
# 95                64339540.5                 0.0                  0.0  2537.0
# 96                64339740.0                 0.0                  0.0  2266.5
# 97                64339743.0                 0.0                  0.0  2217.0
# 98                64339741.0                 0.0                  0.0  2297.0
# 99                64339742.0                 0.0                  0.0  2319.0
#
#     ...  genome dose  genome filter_except_lowest_root  \
# 0   ...          NaN                               NaN
# 1   ...          NaN                               NaN
# 2   ...          NaN                               NaN
# 3   ...          NaN                               NaN
# 4   ...          NaN                               NaN
# ..  ...          ...                               ...
# 95  ...          NaN                               NaN
# 96  ...          NaN                               NaN
# 97  ...          NaN                               NaN
# 98  ...          NaN                               NaN
# 99  ...          NaN                               NaN
#
#     genome filter_lowest_root  genome proc  genome root_id  genome series  \
# 0                         NaN          0.0             1.0        16005.0
# 1                         NaN          0.0             1.0        16005.0
# 2                         NaN          0.0             1.0        16005.0
# 3                         NaN          0.0             1.0        16005.0
# 4                         NaN          0.0             1.0        16005.0
# ..                        ...          ...             ...            ...
# 95                        NaN          0.0             1.0        16005.0
# 96                        NaN          0.0             1.0        16005.0
# 97                        NaN          0.0             1.0        16005.0
# 98                        NaN          0.0             1.0        16005.0
# 99                        NaN          0.0             1.0        16005.0
#
#     genome stint  genome thread  Focal Abundance  \
# 0            1.0            0.0         0.351112
# 1            2.0            0.0         0.370000
# 2            3.0            0.0         0.376667
# 3            4.0            0.0         0.341250
# 4            5.0            0.0         0.513611
# ..           ...            ...              ...
# 95          96.0            0.0         0.237500
# 96          97.0            0.0         0.247500
# 97          98.0            0.0         0.249583
# 98          99.0            0.0         0.214444
# 99         100.0            0.0         0.224722
#
#     Positive Fitness Differential Focal
# 0                                   1.0
# 1                                   1.0
# 2                                   1.0
# 3                                   1.0
# 4                                   1.0
# ..                                  ...
# 95                                  1.0
# 96                                  1.0
# 97                                  1.0
# 98                                  0.0
# 99                                  1.0
#
# [100 rows x 50 columns]

# %%
data_fit.columns
# Out:
# Index(['Competition Stint', 'Competition Series', 'Competition Replicate',
#        'Treatment mut_sever', 'Treatment mut_freq', 'Competition Endeavor',
#        'Competition Slurm Job ID', 'Competition Thread', 'Competition Process',
#        'Update', 'Population Slots', 'Num Live Cells', 'Population Extinct',
#        'Num Live Cells with Focal Root ID', 'Focal Root ID Cells Extinct',
#        'Is Focal Root ID', 'Abundance', 'Prevalence', 'Focal Prevalence',
#        'Root ID', 'Fitness Differential', 'Fitness Differential Focal',
#        'Count', 'Extrospective State Target Idx',
#        'Inter Message Self-Send Filter Mod',
#        'Inter Message Self-Send Filter Target',
#        'Intermittent Extrospective State Exchange Probability',
#        'Intermittent Extrospective State Rotate Probability',
#        'Intermittent Introspective State Exchange Probability',
#        'Intermittent Introspective State Rotate Probability',
#        'Intermittent Writable State Exchange Probability',
#        'Intermittent Writable State Rotate Probability',
#        'Intra Message Self-Send Filter Mod',
#        'Intra Message Self-Send Filter Target',
#        'Introspective State Target Idx',
#        'Mutation Occurence Rate Multiplicand',
#        'Point Mutation Rate Multiplicand', 'Program Max Size Override',
#        'Sequence Defect Rate Multiplicand', 'Writable State Target Idx',
#        'genome dose', 'genome filter_except_lowest_root',
#        'genome filter_lowest_root', 'genome proc', 'genome root_id',
#        'genome series', 'genome stint', 'genome thread', 'Focal Abundance',
#        'Positive Fitness Differential Focal'],
#       dtype='object')

# %%
data = data_df.merge(
    data_fit,
    left_on="Stint",
    right_on="Competition Stint",
    how="inner",
    suffixes=("", "_fit"),
).sort_values("Stint")

# %%
data["Morph"] = data["Morph"].replace(
    {
        "a": 0,
        "b": 1,
        "c": 2,
        "d": 3,
        "e": 4,
        "f": 5,
        "g": 6,
        "h": 7,
        "i": 8,
        "j": 9,
    },
)

# %%
dx = data.loc[
    (data["Stint"] > 1)
].sort_values("Stint")

# %%
sns.regplot(
    y=dx["Critical Fitness Complexity"].rolling(6, center=False, min_periods=1).mean(),
    # y=data["Fitness Differential Focal"],
    x=dx["Stint"],
)
# Out:
# <AxesSubplot:xlabel='Stint', ylabel='Critical Fitness Complexity'>

# %%
sns.regplot(
    y=dx["Fitness Differential Focal"].iloc[::-1].rolling(7, center=False, min_periods=1).mean().iloc[::-1],
    # y=data["Fitness Differential Focal"],
    x=dx["Stint"],
)
# Out:
# <AxesSubplot:xlabel='Stint', ylabel='Fitness Differential Focal'>

# %%
sns.regplot(
    x=dx["Stint"],
    y=dx["Critical Fitness Complexity"] - dx["prevcplx"],
)
# Out:
# <AxesSubplot:xlabel='Stint'>

# %% [markdown]
# Autocorrelation.

# %%
plt.plot(
    np.arange(len(dx)),
    np.correlate(
        (dx["Critical Fitness Complexity"] - dx["prevcplx"]).to_numpy(),
        (dx["Critical Fitness Complexity"] - dx["prevcplx"]).to_numpy(),
        mode="same",
    ),
)

# %%
from scipy import stats as scipy_stats

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4,2), sharey=True)
for shift, ax in ((0, ax1), (-1, ax2)):
    cpx = dx["Critical Fitness Complexity"] - dx["prevcplx"] > 0
    fit = dx["Fitness Differential Focal"].shift(shift)

    sns.violinplot(
        x=cpx,
        hue=cpx,
        y=fit,
        inner="box",
        gap=0.1,
        split=True,
        legend=False,
        ax=ax,
    )
    ax.collections[1].set_edgecolor('gainsboro')
    ax.collections[0].set_edgecolor('gainsboro')
    sns.stripplot(
        x=cpx,
        y=fit,
        ax=ax,
        color="black",
        s=2,
    )
    ax.set_xlabel("Incr G Complexity")
    ax.set_ylabel("Fitness Differential")

    print(
        scipy_stats.mannwhitneyu(
            fit[cpx].dropna(),
            fit[~cpx].dropna(),
            alternative="greater",
        ),
    )

ax1.set_title("Same Stint")
ax2.set_title("Next Stint")

plt.show()

sns.scatterplot(
    x=dx["Critical Fitness Complexity"] - dx["prevcplx"],
    y=dx["Fitness Differential Focal"].shift(shift),
    hue=cpx,
)
# Out:
# MannwhitneyuResult(statistic=1186.0, pvalue=0.6088958580591198)
# MannwhitneyuResult(statistic=1333.0, pvalue=0.17415104213169036)
# <AxesSubplot:xlabel='None', ylabel='Fitness Differential Focal'>

# %%
from scipy import stats as scipy_stats

for sign in 1, -1:
    with tp.teed(
        plt.subplots,
        1, 5, figsize=(8,2), sharey=True,
        teeplot_outattrs={
            "sign": sign,
            "how": "rollingmean",
        },
        teeplot_subdir=teeplot_subdir,
    ) as g:
        fig, axs = g
        for shift, ax in zip(range(10), axs):
            cpx = dx["Critical Fitness Complexity"] - dx["prevcplx"] > 0
            if shift:
                fit = dx["Fitness Differential Focal"].iloc[::sign].rolling(shift, center=False, closed="left", min_periods=1).mean().iloc[::sign]
            else:
                fit = dx["Fitness Differential Focal"]

            sns.violinplot(
                x=cpx,
                hue=cpx,
                y=fit,
                inner="box",
                gap=0.1,
                split=True,
                legend=False,
                ax=ax,
            )
            ax.collections[1].set_edgecolor('gainsboro')
            ax.collections[0].set_edgecolor('gainsboro')
            sns.stripplot(
                x=cpx,
                y=fit,
                ax=ax,
                color="black",
                s=2,
            )
            ax.set_xlabel("Incr G Complexity")
            ax.set_ylabel("Fitness Differential")
            p = scipy_stats.mannwhitneyu(
                fit[cpx].dropna(),
                fit[~cpx].dropna(),
                alternative="greater",
            ).pvalue
            ax.text(0.7, 0.9, f"p={p:.2g}",
                    ha='center', va='center',
                    fontsize=8,
                    transform=ax.transAxes,
                )
            if shift != 2:
                ax.set_xlabel("")

            ax.set_title(f"Shift {-1 * sign * shift}")
# Out:
# teeplots/2025-09-04-complexity-adaptation-all-contemporary/how=rollingmean+sign=1+viz=subplots+ext=.pdf
# teeplots/2025-09-04-complexity-adaptation-all-contemporary/how=rollingmean+sign=1+viz=subplots+ext=.png
# teeplots/2025-09-04-complexity-adaptation-all-contemporary/how=rollingmean+sign=-1+viz=subplots+ext=.pdf
# teeplots/2025-09-04-complexity-adaptation-all-contemporary/how=rollingmean+sign=-1+viz=subplots+ext=.png
