# %%
import boto3
import botocore
from iterdub import iterdub as ib
import matplotlib.pyplot as plt
import pandas as pd
from pandas.util import hash_pandas_object
from scipy import stats
import seaborn as sns
from teeplot import teeplot as tp

# %%
from dishpylib.pyhelpers import print_runtime

# %%
teeplot_subdir = "bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--interface_complexity"

# %%
def make_outattr_metadata(*args, **kwargs):
    return {}

# %%
def override_xlabel(func, xlabel="Transfer Round"):
    def wrapper(*args, **kwargs):
        result = func(*args, **kwargs)
        ax = result if result is not None else plt.gca()
        ax.set_xlabel(xlabel)
        return result
    return wrapper

# %%
print_runtime()
# Out:
# context: ci
# hostname: runnervmp9m8c
# interpreter: 3.10.12 (main, Jun 22 2026, 18:55:27) [GCC 11.4.0]
# notebook name: bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--interface_complexity
# notebook path: /home/runner/work/oee4/oee4/binder/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--interface_complexity.ipynb
# revision: bdac574
# timestamp: 2026-08-15T01:47:28Z00:00
#
# IPython==7.16.1
# packaging==26.2
# <ipython-input-6-4d790cf6450f>:1: DeprecatedWarning: print_runtime is deprecated. use nbmetalog package instead
#   print_runtime()

# %% [markdown]
# # get data

# %%
s3_handle = boto3.resource(
    's3',
    region_name="us-east-2",
    config=botocore.config.Config(
        signature_version=botocore.UNSIGNED,
    ),
)
bucket_handle = s3_handle.Bucket('prq49')

series_profiles, = bucket_handle.objects.filter(
    Prefix=f'endeavor=16/series-profiles/stage=8+what=elaborated/',
)

# %%
df = pd.read_csv(
    f's3://prq49/{series_profiles.key}',
    compression='xz',
)
dfdigest = '{:x}'.format( hash_pandas_object( df ).sum() )
dfdigest
# Out:
# <ipython-input-8-747b1fe91af5>:1: DtypeWarning: Columns (286,293,300,301,302,303,305,306,307,308,314,315,316,317,318,324,325,326) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# '-2cf7ba7a12df2efc'

# %%
for stint in df['Stint'].unique():
    exec(f'df{stint} = df[ df["Stint"] == {stint} ]')

# %%
dfm10 = df[ df['Stint'] % 10 == 0 ]

# %%
for what in 16005, 16018, 16021:
    with tp.teed(
        sns.lineplot,
        data=dfm10,
        x="Stint",
        y="Cardinal Interface Complexity",
        hue="Series",
        alpha=0.5,
        legend=False,
        lw=1,
        teeplot_outattrs={"what": what},
        teeplot_subdir=teeplot_subdir,
    ) as ax:
        ax.figure.set_size_inches(4.5, 1.5)
        sns.lineplot(
            data=dfm10[dfm10["Series"] == what],
            x="Stint",
            y="Cardinal Interface Complexity",
            color="white",
            lw=5,
            alpha=0.8,
        )
        sns.lineplot(
            data=dfm10[dfm10["Series"] == what],
            x="Stint",
            y="Cardinal Interface Complexity",
            color="tab:blue",
            lw=1.5,
        )
        sns.despine(ax=ax)
        ax.set_ylabel("Phenotype\nComplexity")
        ax.set_xlabel("Transfer Round")
# Out:
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--interface_complexity/hue=series+viz=lineplot+what=16005+x=stint+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--interface_complexity/hue=series+viz=lineplot+what=16005+x=stint+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--interface_complexity/hue=series+viz=lineplot+what=16018+x=stint+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--interface_complexity/hue=series+viz=lineplot+what=16018+x=stint+y=cardinal-interface-complexity+ext=.png
# teeplots/bucket=prq49--a=all_stints_all_series_profiles+endeavor=16--interface_complexity/hue=series+viz=lineplot+what=16021+x=stint+y=cardinal-interface-complexity+ext=.pdf
# ...

# %% [markdown]
# # how does state interface complexity change over time?

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10,
    x='Stint',
    y='Num Less Fit Under State Perturbation',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-state-perturbation+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-state-perturbation+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Num Less Fit Under State Perturbation'>

# %%
def swarmplot_boxplot(*args, **kwargs):
    sns.swarmplot(
        *args,
        **kwargs,
        edgecolor='w',
        linewidth=0.5,
        s=4,
    )
    sns.boxplot(
        *args,
        **kwargs,
    )

tp.tee(
    override_xlabel(swarmplot_boxplot),
    data=dfm10,
    x='Stint',
    y='Num Less Fit Under State Perturbation',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 37.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 30.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 27.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# # how does intra messaging complexity change over time?

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10,
    x='Stint',
    y='Num Less Fit Under Intra Self-Send @ Filter Mod 20',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-intra-self-send-filter-mod-20+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-intra-self-send-filter-mod-20+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Num Less Fit Under Intra Self-Send @ Filter Mod 20'>

# %%
def swarmplot_boxplot(*args, **kwargs):
    sns.swarmplot(
        *args,
        **kwargs,
        edgecolor='w',
        linewidth=0.5,
        s=4,
    )
    sns.boxplot(
        *args,
        **kwargs,
    )

tp.tee(
    override_xlabel(swarmplot_boxplot),
    data=dfm10,
    x='Stint',
    y='Num Less Fit Under Intra Self-Send @ Filter Mod 20',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 80.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 81.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 77.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 86.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# # how does inter messaging complexity change over time?

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10,
    x='Stint',
    y='Num Less Fit Under Inter Self-Send @ Filter Mod 20',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-inter-self-send-filter-mod-20+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-inter-self-send-filter-mod-20+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Num Less Fit Under Inter Self-Send @ Filter Mod 20'>

# %%
def swarmplot_boxplot(*args, **kwargs):
    sns.swarmplot(
        *args,
        **kwargs,
        edgecolor='w',
        linewidth=0.5,
        s=4,
    )
    sns.boxplot(
        *args,
        **kwargs,
    )

tp.tee(
    override_xlabel(swarmplot_boxplot),
    data=dfm10,
    x='Stint',
    y='Num Less Fit Under Inter Self-Send @ Filter Mod 20',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 62.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 56.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 52.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 47.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# # how does cell interface complexity change over time?

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10,
    x='Stint',
    y='Cell Interface Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cell-interface-complexity+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cell-interface-complexity+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Cell Interface Complexity'>

# %%
def swarmplot_boxplot(*args, **kwargs):
    sns.swarmplot(
        *args,
        **kwargs,
        edgecolor='w',
        linewidth=0.5,
        s=4,
    )
    sns.boxplot(
        *args,
        **kwargs,
    )

tp.tee(
    override_xlabel(swarmplot_boxplot),
    data=dfm10,
    x='Stint',
    y='Cell Interface Complexity',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 32.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 15.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 30.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
tp.tee(
    override_xlabel(sns.barplot),
    data=dfm10,
    x='Stint',
    y='Cell Interface Complexity',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/teeplot/teeplot.py:324: UserWarning: teeplot already created file teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cell-interface-complexity+ext=.pdf, overwriting it
#   warnings.warn(
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cell-interface-complexity+ext=.pdf
# /usr/local/lib/python3.10/dist-packages/teeplot/teeplot.py:324: UserWarning: teeplot already created file teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cell-interface-complexity+ext=.png, overwriting it
#   warnings.warn(
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cell-interface-complexity+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Cell Interface Complexity'>

# %% [markdown]
# # how does cardinal interface complexity change over time?

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10,
    x='Stint',
    y='Cardinal Interface Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cardinal-interface-complexity+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Cardinal Interface Complexity'>

# %%
def swarmplot_boxplot(*args, **kwargs):
    sns.swarmplot(
        *args,
        **kwargs,
        edgecolor='w',
        linewidth=0.5,
        s=4,
    )
    sns.boxplot(
        *args,
        **kwargs,
    )

tp.tee(
    override_xlabel(swarmplot_boxplot),
    data=dfm10,
    x='Stint',
    y='Cardinal Interface Complexity',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 30.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 16.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3399: UserWarning: 27.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
tp.tee(
    override_xlabel(sns.barplot),
    data=dfm10,
    x='Stint',
    y='Cardinal Interface Complexity',
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/teeplot/teeplot.py:324: UserWarning: teeplot already created file teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cardinal-interface-complexity+ext=.pdf, overwriting it
#   warnings.warn(
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cardinal-interface-complexity+ext=.pdf
# /usr/local/lib/python3.10/dist-packages/teeplot/teeplot.py:324: UserWarning: teeplot already created file teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cardinal-interface-complexity+ext=.png, overwriting it
#   warnings.warn(
# teeplots/bucket=prq49+endeavor=16+transform=filter-Stint-mod10+viz=wrapper+x=stint+y=cardinal-interface-complexity+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Cardinal Interface Complexity'>

# %% [markdown]
# # case study: series 16005

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10[ dfm10['Series'] == 16005 ],
    x='Stint',
    y='Cardinal Interface Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16005~Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~Stint-mod10+viz=wrapper+x=stint+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~Stint-mod10+viz=wrapper+x=stint+y=cardinal-interface-complexity+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Cardinal Interface Complexity'>

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10[ dfm10['Series'] == 16005 ],
    x='Stint',
    y='Cell Interface Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16005~Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~Stint-mod10+viz=wrapper+x=stint+y=cell-interface-complexity+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~Stint-mod10+viz=wrapper+x=stint+y=cell-interface-complexity+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Cell Interface Complexity'>

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10[ dfm10['Series'] == 16005 ],
    x='Stint',
    y='Num Less Fit Under State Perturbation',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16005~Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-state-perturbation+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-state-perturbation+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Num Less Fit Under State Perturbation'>

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10[ dfm10['Series'] == 16005 ],
    x='Stint',
    y='Num Less Fit Under Intra Self-Send @ Filter Mod 20',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16005~Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-intra-self-send-filter-mod-20+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-intra-self-send-filter-mod-20+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Num Less Fit Under Intra Self-Send @ Filter Mod 20'>

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10[ dfm10['Series'] == 16005 ],
    x='Stint',
    y='Num Less Fit Under Inter Self-Send @ Filter Mod 20',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16005~Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-inter-self-send-filter-mod-20+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16005~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-inter-self-send-filter-mod-20+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Num Less Fit Under Inter Self-Send @ Filter Mod 20'>

# %% [markdown]
# # Case Study: Series 16021

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10[ dfm10['Series'] == 16021 ],
    x='Stint',
    y='Cardinal Interface Complexity',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16021~Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16021~Stint-mod10+viz=wrapper+x=stint+y=cardinal-interface-complexity+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16021~Stint-mod10+viz=wrapper+x=stint+y=cardinal-interface-complexity+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Cardinal Interface Complexity'>

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10[ dfm10['Series'] == 16021 ],
    x='Stint',
    y='Num Less Fit Under Writable State Exchanges',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16021~Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16021~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-writable-state-exchanges+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16021~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-writable-state-exchanges+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Num Less Fit Under Writable State Exchanges'>

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10[ dfm10['Series'] == 16021 ],
    x='Stint',
    y='Num Less Fit Under State Perturbation',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16021~Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16021~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-state-perturbation+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16021~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-state-perturbation+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Num Less Fit Under State Perturbation'>

# %%
tp.tee(
    override_xlabel(sns.lineplot),
    data=dfm10[ dfm10['Series'] == 16021 ],
    x='Stint',
    y='Num Less Fit Under Inter Self-Send @ Filter Mod 20',
    hue='Series',
    legend=False,
    teeplot_outattrs={
        **{
            'bucket' : ib.dub( df['Bucket'] ),
            'endeavor' : ib.dub( df['Endeavor'].astype(int) ),
            'transform' : 'filter-Series-16021~Stint-mod10',
            '_dfdigest' : dfdigest,
        },
        **make_outattr_metadata(),
    },
)
# Out:
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16021~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-inter-self-send-filter-mod-20+ext=.pdf
# teeplots/bucket=prq49+endeavor=16+hue=series+transform=filter-Series-16021~Stint-mod10+viz=wrapper+x=stint+y=num-less-fit-under-inter-self-send-filter-mod-20+ext=.png
# <AxesSubplot:xlabel='Transfer Round', ylabel='Num Less Fit Under Inter Self-Send @ Filter Mod 20'>
